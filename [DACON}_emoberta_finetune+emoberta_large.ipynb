# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.8/dist-packages (4.25.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.11.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)

# %%
import torch
import random
import numpy as np

# set_seed(42) 
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
from transformers import set_seed, AutoTokenizer, AutoConfig, AutoModelForSequenceClassification

model_config = AutoConfig.from_pretrained('tae898/emoberta-large', num_labels=7)
model = AutoModelForSequenceClassification.from_pretrained('tae898/emoberta-large', config=model_config)

tokenizer = AutoTokenizer.from_pretrained('tae898/emoberta-large')
# tokenizer.padding_side = "left" # Very Important
# tokenizer.pad_token = tokenizer.eos_token

model.resize_token_embeddings(len(tokenizer))
model.config.pad_token_id = model.config.eos_token_id

# %%
import pandas as pd

pd.read_csv("./data_info.csv", encoding="cp949")
# Out:
#        feature     information    type
# 0           ID            고유번호  object
# 1    Utterance             발화문  object
# 2      Speaker             발화자  object
# 3  Dialogue_ID  Dialogue 구분 번호     int
# 4       Target             감정   object

# %%
import os
import pandas as pd
from torch.utils.data import Dataset

class CustomDataset(Dataset):
    def __init__(self, train=True):
        super().__init__()
        self.train = train
        self.data = pd.read_csv(os.path.join('./', 'train.csv' if train else 'test.csv'))
        if self.train:
          self.data['Target'] = self.data['Target'].replace({'neutral':0, 'surprise':1, 'fear':2, 'sadness':3, 'joy':4, 'disgust':5, 'anger':6})

    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, index):
        record = self.data.iloc[index]       
        text = record['Utterance']
        if self.train:
            return {'text': text, 'label': record['Target']}
        else:
            return {'text': text, 'label': '0'}

train_dataset = CustomDataset(train=True)

# %%
class ClassificationCollator(object):
    def __init__(self, tokenizer, max_seq_len=None):
        self.tokenizer = tokenizer
        self.max_seq_len = max_seq_len
        
        return
    
    def __call__(self, sequences):
        texts = [sequence['text'] for sequence in sequences]
        labels = [int(sequence['label']) for sequence in sequences]
        inputs = self.tokenizer(text=texts,
                                return_tensors='pt',
                                padding=True,
                                truncation=True,
                                max_length=self.max_seq_len)
        inputs.update({'labels': torch.tensor(labels)})
        
        return inputs

ClassificationCollator = ClassificationCollator(tokenizer=tokenizer, max_seq_len=512)

# %%
from torch.utils.data import DataLoader, random_split

train_size = int(len(train_dataset) * 0.8)
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])

train_dataloader = DataLoader(dataset=train_dataset,
                              batch_size=16,
                              shuffle=True,
                              collate_fn=ClassificationCollator)

val_dataloader = DataLoader(dataset=val_dataset,
                            batch_size=16,
                            shuffle=False,
                            collate_fn=ClassificationCollator)

# %%
from transformers import AdamW, get_cosine_schedule_with_warmup

total_epochs = 1

param_optimizer = list(model.named_parameters())
no_decay = ['bias', 'LayerNorm.bias', 'LayerNorm.weight']
optimizer_grouped_parameters = [
    {'params': [p for n, p in param_optimizer if not any(nd in n for nd in no_decay)], 'weight_decay': 0.01},
    {'params': [p for n, p in param_optimizer if any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
]
optimizer = AdamW(optimizer_grouped_parameters,
                  lr=1e-5,
                  eps=1e-8)

num_train_steps = len(train_dataloader) * total_epochs
num_warmup_steps = int(num_train_steps * 0.1) 

lr_scheduler = get_cosine_schedule_with_warmup(optimizer,
                                               num_warmup_steps=num_warmup_steps,
                                               num_training_steps = num_train_steps)
# Out:
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
import torch

def train(dataloader, optimizer, scheduler, device_):
    global model
    model.train()
    
    prediction_labels = []
    true_labels = []
    
    total_loss = []
    
    for batch in dataloader:
        true_labels += batch['labels'].numpy().flatten().tolist()
        batch = {k:v.type(torch.long).to(device_) for k, v in batch.items()}
        
        
        outputs = model(**batch)
        loss, logits = outputs[:2]
        logits = logits.detach().cpu().numpy()
        total_loss.append(loss.item())
        
        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0) # prevent exploding gradient

        optimizer.step()
        scheduler.step()
        
        prediction_labels += logits.argmax(axis=-1).flatten().tolist()
    
    return true_labels, prediction_labels, total_loss

def validation(dataloader, device_):
    global model
    model.eval()
    
    prediction_labels = []
    true_labels = []
    
    total_loss = []
    
    for batch in dataloader:
        true_labels += batch['labels'].numpy().flatten().tolist()
        batch = {k:v.type(torch.long).to(device_) for k, v in batch.items()}
        
        with torch.no_grad():
            outputs = model(**batch)
            loss, logits = outputs[:2]
            logits = logits.detach().cpu().numpy()
            total_loss.append(loss.item())

            prediction_labels += logits.argmax(axis=-1).flatten().tolist()
        
    return true_labels, prediction_labels, total_loss

# %%
from sklearn.metrics import classification_report, accuracy_score

device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

all_loss = {'train_loss': [], 'val_loss': []}
all_acc = {'train_acc': [], 'val_acc': []}

for epoch in range(total_epochs):
    y, y_pred, train_loss = train(train_dataloader, optimizer, lr_scheduler, device)
    train_acc = accuracy_score(y, y_pred)
    
    y, y_pred, val_loss = validation(val_dataloader, device)
    val_acc = accuracy_score(y, y_pred)
    
    all_loss['train_loss'] += train_loss
    all_loss['val_loss'] += val_loss
    
    all_acc['train_acc'].append(train_acc)
    all_acc['val_acc'].append(val_acc)
    
    print(f'Epoch: {epoch}, train_loss: {torch.tensor(train_loss).mean():.3f}, train_acc: {train_acc:.3f}, val_loss: {torch.tensor(val_loss).mean():.3f}, val_acc: {val_acc:.3f}')

# %%
model.save_pretrained('./best_model')
tokenizer.save_pretrained("./best_model/")
# Out:
# ('/content/drive/MyDrive/[DACON]sentiment_classification/best_model/tokenizer_config.json',
#  '/content/drive/MyDrive/[DACON]sentiment_classification/best_model/special_tokens_map.json',
#  '/content/drive/MyDrive/[DACON]sentiment_classification/best_model/vocab.json',
#  '/content/drive/MyDrive/[DACON]sentiment_classification/best_model/merges.txt',
#  '/content/drive/MyDrive/[DACON]sentiment_classification/best_model/added_tokens.json',
#  '/content/drive/MyDrive/[DACON]sentiment_classification/best_model/tokenizer.json')

# %%
test = pd.read_csv('./test.csv')
test_list = test["Utterance"].values.tolist()

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

def sentiment_classification(modelname):
    result = list()
    final_labels = list()

    model = modelname

    tokenizer = AutoTokenizer.from_pretrained(model)    
    
    model = AutoModelForSequenceClassification.from_pretrained(model)

    classification = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer, device=0)

    for i in range(len(test_list)):
        print(classification(test_list[i]))
        result.append(classification(test_list[i]))

    for i in range(len(result)):
        for j in range(len(result[i])):
            final_labels.append([result[i][j]['label'], result[i][j]['score']])
    
    return final_labels

# %%
inference01 = sentiment_classification("./best_model")
# Out:
# [{'label': 'joy', 'score': 0.995347797870636}]
# [{'label': 'neutral', 'score': 0.9997523427009583}]
# [{'label': 'neutral', 'score': 0.8349255323410034}]
# [{'label': 'neutral', 'score': 0.9976422190666199}]
# [{'label': 'sadness', 'score': 0.9960768818855286}]
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1043: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# [{'label': 'sadness', 'score': 0.9960797429084778}]
# [{'label': 'sadness', 'score': 0.990605890750885}]
# [{'label': 'sadness', 'score': 0.9989331364631653}]
# [{'label': 'fear', 'score': 0.9866005778312683}]
# [{'label': 'sadness', 'score': 0.9960768818855286}]
# [{'label': 'sadness', 'score': 0.9960768818855286}]
# [{'label': 'neutral', 'score': 0.9978815913200378}]
# [{'label': 'sadness', 'score': 0.9891023635864258}]
# [{'label': 'neutral', 'score': 0.7437227368354797}]
# [{'label': 'sadness', 'score': 0.9989011287689209}]
# [{'label': 'sadness', 'score': 0.7908764481544495}]
# [{'label': 'neutral', 'score': 0.9992433786392212}]
# [{'label': 'neutral', 'score': 0.5921871662139893}]
# [{'label': 'sadness', 'score': 0.9991406202316284}]
# [{'label': 'sadness', 'score': 0.9991406202316284}]
# [{'label': 'neutral', 'score': 0.9978815913200378}]
# [{'label': 'neutral', 'score': 0.5623016357421875}]
# [{'label': 'neutral', 'score': 0.9984623193740845}]
# [{'label': 'fear', 'score': 0.9959851503372192}]
# [{'label': 'neutral', 'score': 0.9988172054290771}]
# [{'label': 'neutral', 'score': 0.9984800219535828}]
# [{'label': 'neutral', 'score': 0.9975900650024414}]
# [{'label': 'disgust', 'score': 0.9978477954864502}]
# [{'label': 'sadness', 'score': 0.999016284942627}]
# [{'label': 'joy', 'score': 0.995245635509491}]
# [{'label': 'neutral', 'score': 0.8979580998420715}]
# [{'label': 'sadness', 'score': 0.6186519265174866}]
# [{'label': 'joy', 'score': 0.9962945580482483}]
# [{'label': 'anger', 'score': 0.8834087252616882}]
# [{'label': 'joy', 'score': 0.9669790267944336}]
# [{'label': 'sadness', 'score': 0.9985223412513733}]
# [{'label': 'fear', 'score': 0.9984651803970337}]
# [{'label': 'neutral', 'score': 0.9995385408401489}]
# [{'label': 'joy', 'score': 0.998428463935852}]
# [{'label': 'neutral', 'score': 0.997885525226593}]
# [{'label': 'neutral', 'score': 0.997885525226593}]
# [{'label': 'neutral', 'score': 0.9967549443244934}]
# [{'label': 'anger', 'score': 0.8228629231452942}]
# [{'label': 'neutral', 'score': 0.9940464496612549}]
# [{'label': 'neutral', 'score': 0.9994760155677795}]
# [{'label': 'neutral', 'score': 0.9802431464195251}]
# [{'label': 'neutral', 'score': 0.9996371269226074}]
# [{'label': 'neutral', 'score': 0.9997022747993469}]
# [{'label': 'neutral', 'score': 0.9993182420730591}]
# [{'label': 'joy', 'score': 0.9971684813499451}]
# [{'label': 'sadness', 'score': 0.9751064777374268}]
# [{'label': 'neutral', 'score': 0.9885848164558411}]
# [{'label': 'neutral', 'score': 0.8515984416007996}]
# [{'label': 'neutral', 'score': 0.9997314810752869}]
# [{'label': 'sadness', 'score': 0.9902645349502563}]
# [{'label': 'sadness', 'score': 0.8284707069396973}]
# [{'label': 'neutral', 'score': 0.8226918578147888}]
# [{'label': 'joy', 'score': 0.9721729159355164}]
# [{'label': 'joy', 'score': 0.7508276104927063}]
# [{'label': 'fear', 'score': 0.9779489040374756}]
# [{'label': 'sadness', 'score': 0.9989197254180908}]
# [{'label': 'neutral', 'score': 0.6890297532081604}]
# [{'label': 'neutral', 'score': 0.9992061257362366}]
# [{'label': 'neutral', 'score': 0.9775305390357971}]
# [{'label': 'neutral', 'score': 0.9992953538894653}]
# [{'label': 'sadness', 'score': 0.9965985417366028}]
# [{'label': 'sadness', 'score': 0.998722493648529}]
# [{'label': 'neutral', 'score': 0.9997376799583435}]
# [{'label': 'neutral', 'score': 0.9997765421867371}]
# [{'label': 'joy', 'score': 0.998629093170166}]
# [{'label': 'joy', 'score': 0.9970836043357849}]
# [{'label': 'neutral', 'score': 0.9873449206352234}]
# [{'label': 'joy', 'score': 0.6914094686508179}]
# [{'label': 'anger', 'score': 0.6712079644203186}]
# [{'label': 'joy', 'score': 0.9985816478729248}]
# [{'label': 'sadness', 'score': 0.6074987053871155}]
# [{'label': 'anger', 'score': 0.9042508602142334}]
# [{'label': 'anger', 'score': 0.9906602501869202}]
# [{'label': 'neutral', 'score': 0.9807828068733215}]
# [{'label': 'sadness', 'score': 0.9026154279708862}]
# [{'label': 'anger', 'score': 0.9663028120994568}]
# [{'label': 'joy', 'score': 0.9986087679862976}]
# [{'label': 'neutral', 'score': 0.9996926784515381}]
# [{'label': 'neutral', 'score': 0.9993958473205566}]
# [{'label': 'fear', 'score': 0.4900355041027069}]
# [{'label': 'neutral', 'score': 0.9984793066978455}]
# [{'label': 'anger', 'score': 0.9987710118293762}]
# [{'label': 'neutral', 'score': 0.9996091723442078}]
# [{'label': 'fear', 'score': 0.6181228160858154}]
# [{'label': 'anger', 'score': 0.9990652203559875}]
# [{'label': 'neutral', 'score': 0.7404019832611084}]
# [{'label': 'neutral', 'score': 0.9954555034637451}]
# [{'label': 'neutral', 'score': 0.9978815913200378}]
# [{'label': 'joy', 'score': 0.9974451065063477}]
# [{'label': 'neutral', 'score': 0.9997196793556213}]
# [{'label': 'neutral', 'score': 0.8125892877578735}]
# [{'label': 'fear', 'score': 0.9827889800071716}]
# [{'label': 'fear', 'score': 0.9991581439971924}]
# [{'label': 'sadness', 'score': 0.9685985445976257}]
# [{'label': 'neutral', 'score': 0.9987404942512512}]
# [{'label': 'neutral', 'score': 0.9996994733810425}]
# [{'label': 'sadness', 'score': 0.9967430233955383}]
# [{'label': 'neutral', 'score': 0.602899432182312}]
# [{'label': 'neutral', 'score': 0.9722673296928406}]
# [{'label': 'sadness', 'score': 0.9987096786499023}]
# [{'label': 'sadness', 'score': 0.9988272786140442}]
# [{'label': 'joy', 'score': 0.7311609387397766}]
# [{'label': 'neutral', 'score': 0.9960565567016602}]
# [{'label': 'neutral', 'score': 0.993467390537262}]
# [{'label': 'neutral', 'score': 0.9987046718597412}]
# [{'label': 'neutral', 'score': 0.9997348189353943}]
# [{'label': 'sadness', 'score': 0.9941776990890503}]
# [{'label': 'neutral', 'score': 0.9698430299758911}]
# [{'label': 'neutral', 'score': 0.9885848164558411}]
# [{'label': 'neutral', 'score': 0.5360967516899109}]
# [{'label': 'neutral', 'score': 0.999559223651886}]
# [{'label': 'joy', 'score': 0.9784653782844543}]
# [{'label': 'neutral', 'score': 0.9991224408149719}]
# [{'label': 'fear', 'score': 0.9958819150924683}]
# [{'label': 'fear', 'score': 0.903693675994873}]
# [{'label': 'fear', 'score': 0.9864655137062073}]
# [{'label': 'joy', 'score': 0.9988333582878113}]
# [{'label': 'sadness', 'score': 0.9088813066482544}]
# [{'label': 'sadness', 'score': 0.9088813066482544}]
# [{'label': 'sadness', 'score': 0.9088813066482544}]
# [{'label': 'neutral', 'score': 0.9995821118354797}]
# [{'label': 'sadness', 'score': 0.9981542229652405}]
# [{'label': 'sadness', 'score': 0.9968841671943665}]
# [{'label': 'sadness', 'score': 0.9962284564971924}]
# [{'label': 'neutral', 'score': 0.998600423336029}]
# [{'label': 'sadness', 'score': 0.9932960867881775}]
# [{'label': 'sadness', 'score': 0.998883068561554}]
# [{'label': 'neutral', 'score': 0.6669774055480957}]
# [{'label': 'fear', 'score': 0.6311373710632324}]
# [{'label': 'neutral', 'score': 0.6853617429733276}]
# [{'label': 'neutral', 'score': 0.7304263710975647}]
# [{'label': 'neutral', 'score': 0.7304263710975647}]
# [{'label': 'fear', 'score': 0.9991193413734436}]
# [{'label': 'neutral', 'score': 0.9997641444206238}]
# [{'label': 'neutral', 'score': 0.9994218349456787}]
# [{'label': 'neutral', 'score': 0.7323341965675354}]
# [{'label': 'neutral', 'score': 0.9890502691268921}]
# [{'label': 'fear', 'score': 0.8873844742774963}]
# [{'label': 'neutral', 'score': 0.9991773962974548}]
# [{'label': 'sadness', 'score': 0.981751024723053}]
# [{'label': 'neutral', 'score': 0.4606315791606903}]
# [{'label': 'neutral', 'score': 0.9997338652610779}]
# [{'label': 'fear', 'score': 0.8269572257995605}]
# [{'label': 'neutral', 'score': 0.9997223019599915}]
# [{'label': 'neutral', 'score': 0.999601423740387}]
# [{'label': 'neutral', 'score': 0.9993189573287964}]
# [{'label': 'joy', 'score': 0.6426160931587219}]
# [{'label': 'fear', 'score': 0.9990899562835693}]
# [{'label': 'sadness', 'score': 0.9549533128738403}]
# [{'label': 'joy', 'score': 0.998603880405426}]
# [{'label': 'fear', 'score': 0.9967065453529358}]
# [{'label': 'sadness', 'score': 0.9813421368598938}]
# [{'label': 'neutral', 'score': 0.75007164478302}]
# [{'label': 'anger', 'score': 0.8261414170265198}]
# [{'label': 'neutral', 'score': 0.9766998291015625}]
# [{'label': 'disgust', 'score': 0.9987109899520874}]
# [{'label': 'fear', 'score': 0.8088743090629578}]
# [{'label': 'neutral', 'score': 0.9989163875579834}]
# [{'label': 'neutral', 'score': 0.9981124401092529}]
# [{'label': 'surprise', 'score': 0.9880461692810059}]
# [{'label': 'fear', 'score': 0.9985271692276001}]
# [{'label': 'neutral', 'score': 0.9989058971405029}]
# [{'label': 'neutral', 'score': 0.9994101524353027}]
# [{'label': 'sadness', 'score': 0.9901344180107117}]
# [{'label': 'neutral', 'score': 0.9987934827804565}]
# [{'label': 'neutral', 'score': 0.9991124272346497}]
# [{'label': 'neutral', 'score': 0.9996932744979858}]
# [{'label': 'anger', 'score': 0.9946381449699402}]
# [{'label': 'neutral', 'score': 0.9994276165962219}]
# [{'label': 'fear', 'score': 0.9857528805732727}]
# [{'label': 'fear', 'score': 0.745594322681427}]
# [{'label': 'anger', 'score': 0.9887692928314209}]
# [{'label': 'fear', 'score': 0.9854183197021484}]
# [{'label': 'neutral', 'score': 0.9996728897094727}]
# [{'label': 'fear', 'score': 0.9990667700767517}]
# [{'label': 'neutral', 'score': 0.9997228980064392}]
# [{'label': 'sadness', 'score': 0.5329185724258423}]
# [{'label': 'neutral', 'score': 0.6452659964561462}]
# [{'label': 'anger', 'score': 0.9983596205711365}]
# [{'label': 'joy', 'score': 0.989769697189331}]
# [{'label': 'fear', 'score': 0.9989833235740662}]
# [{'label': 'neutral', 'score': 0.9995951056480408}]
# [{'label': 'neutral', 'score': 0.9996622800827026}]
# [{'label': 'neutral', 'score': 0.9930156469345093}]
# [{'label': 'sadness', 'score': 0.9025329947471619}]
# [{'label': 'neutral', 'score': 0.9975058436393738}]
# [{'label': 'neutral', 'score': 0.5379092693328857}]
# [{'label': 'neutral', 'score': 0.9995484948158264}]
# [{'label': 'neutral', 'score': 0.9993416666984558}]
# [{'label': 'neutral', 'score': 0.9997542500495911}]
# [{'label': 'neutral', 'score': 0.9994738698005676}]
# [{'label': 'neutral', 'score': 0.6655818819999695}]
# [{'label': 'anger', 'score': 0.9363833665847778}]
# [{'label': 'sadness', 'score': 0.9989307522773743}]
# [{'label': 'joy', 'score': 0.9979727864265442}]
# [{'label': 'sadness', 'score': 0.9968841671943665}]
# [{'label': 'neutral', 'score': 0.997885525226593}]
# [{'label': 'anger', 'score': 0.8072381615638733}]
# [{'label': 'neutral', 'score': 0.9929018616676331}]
# [{'label': 'anger', 'score': 0.8704718947410583}]
# [{'label': 'neutral', 'score': 0.8979580998420715}]
# [{'label': 'neutral', 'score': 0.8772261738777161}]
# [{'label': 'neutral', 'score': 0.9260082840919495}]
# [{'label': 'anger', 'score': 0.9931636452674866}]
# [{'label': 'fear', 'score': 0.9986625909805298}]
# [{'label': 'fear', 'score': 0.9915347695350647}]
# [{'label': 'sadness', 'score': 0.9580345749855042}]
# [{'label': 'sadness', 'score': 0.9993809461593628}]
# [{'label': 'neutral', 'score': 0.9957414865493774}]
# [{'label': 'neutral', 'score': 0.4752950072288513}]
# [{'label': 'fear', 'score': 0.9822370409965515}]
# [{'label': 'neutral', 'score': 0.9987949132919312}]
# [{'label': 'sadness', 'score': 0.9976075887680054}]
# [{'label': 'sadness', 'score': 0.6180408596992493}]
# [{'label': 'neutral', 'score': 0.8646299839019775}]
# [{'label': 'surprise', 'score': 0.997846245765686}]
# [{'label': 'neutral', 'score': 0.9978815913200378}]
# [{'label': 'sadness', 'score': 0.9944074153900146}]
# [{'label': 'neutral', 'score': 0.9778100252151489}]
# [{'label': 'surprise', 'score': 0.8787166476249695}]
# [{'label': 'neutral', 'score': 0.637482762336731}]
# [{'label': 'sadness', 'score': 0.9088813066482544}]
# [{'label': 'neutral', 'score': 0.999638557434082}]
# [{'label': 'joy', 'score': 0.9936745166778564}]
# [{'label': 'neutral', 'score': 0.4804784655570984}]
# [{'label': 'fear', 'score': 0.8506943583488464}]
# [{'label': 'surprise', 'score': 0.742881178855896}]
# [{'label': 'neutral', 'score': 0.9338053464889526}]
# [{'label': 'joy', 'score': 0.4155622124671936}]
# [{'label': 'joy', 'score': 0.9962945580482483}]
# [{'label': 'sadness', 'score': 0.9903672933578491}]
# [{'label': 'neutral', 'score': 0.9981077909469604}]
# [{'label': 'fear', 'score': 0.9991680383682251}]
# [{'label': 'neutral', 'score': 0.8571431636810303}]
# [{'label': 'fear', 'score': 0.7612530589103699}]
# [{'label': 'sadness', 'score': 0.9988960027694702}]
# [{'label': 'sadness', 'score': 0.9991388320922852}]
# [{'label': 'neutral', 'score': 0.795300304889679}]
# [{'label': 'neutral', 'score': 0.9992542862892151}]
# [{'label': 'joy', 'score': 0.9641971588134766}]
# [{'label': 'sadness', 'score': 0.9657341241836548}]
# [{'label': 'sadness', 'score': 0.9963907599449158}]
# [{'label': 'sadness', 'score': 0.9944074153900146}]
# [{'label': 'neutral', 'score': 0.997885525226593}]
# [{'label': 'neutral', 'score': 0.9992857575416565}]
# [{'label': 'anger', 'score': 0.9983263611793518}]
# [{'label': 'neutral', 'score': 0.9976763129234314}]
# [{'label': 'anger', 'score': 0.9955961108207703}]
# [{'label': 'neutral', 'score': 0.8630616664886475}]
# [{'label': 'neutral', 'score': 0.9995198249816895}]
# [{'label': 'sadness', 'score': 0.5824828147888184}]
# [{'label': 'fear', 'score': 0.9207936525344849}]
# [{'label': 'neutral', 'score': 0.9984493255615234}]
# [{'label': 'surprise', 'score': 0.9127662181854248}]
# [{'label': 'fear', 'score': 0.998019814491272}]
# [{'label': 'sadness', 'score': 0.8523048162460327}]
# [{'label': 'neutral', 'score': 0.9988158941268921}]
# [{'label': 'neutral', 'score': 0.9997143149375916}]
# [{'label': 'sadness', 'score': 0.9267783164978027}]
# [{'label': 'joy', 'score': 0.988854169845581}]
# [{'label': 'neutral', 'score': 0.999326229095459}]
# [{'label': 'fear', 'score': 0.8606168627738953}]
# [{'label': 'neutral', 'score': 0.9808112382888794}]
# [{'label': 'neutral', 'score': 0.9995997548103333}]
# [{'label': 'joy', 'score': 0.9984856247901917}]
# [{'label': 'neutral', 'score': 0.8979580998420715}]
# [{'label': 'joy', 'score': 0.9351838231086731}]
# [{'label': 'neutral', 'score': 0.7720939517021179}]
# [{'label': 'sadness', 'score': 0.7628225088119507}]
# [{'label': 'neutral', 'score': 0.9997598528862}]
# [{'label': 'fear', 'score': 0.9351434707641602}]
# [{'label': 'sadness', 'score': 0.9564115405082703}]
# [{'label': 'sadness', 'score': 0.9987781643867493}]
# [{'label': 'sadness', 'score': 0.999000608921051}]
# [{'label': 'joy', 'score': 0.9990887641906738}]
# [{'label': 'joy', 'score': 0.9974995255470276}]
# [{'label': 'joy', 'score': 0.8749412894248962}]
# [{'label': 'anger', 'score': 0.9985567927360535}]
# [{'label': 'neutral', 'score': 0.5304372906684875}]
# [{'label': 'sadness', 'score': 0.995394229888916}]
# [{'label': 'neutral', 'score': 0.9991101622581482}]
# [{'label': 'sadness', 'score': 0.9773050546646118}]
# [{'label': 'sadness', 'score': 0.9948658347129822}]
# [{'label': 'sadness', 'score': 0.9945250749588013}]
# [{'label': 'neutral', 'score': 0.9885848164558411}]
# [{'label': 'neutral', 'score': 0.9995601773262024}]
# [{'label': 'anger', 'score': 0.7247798442840576}]
# [{'label': 'neutral', 'score': 0.9993640780448914}]
# [{'label': 'neutral', 'score': 0.9997444748878479}]
# [{'label': 'joy', 'score': 0.9991855025291443}]
# [{'label': 'anger', 'score': 0.971010148525238}]
# [{'label': 'anger', 'score': 0.9978039860725403}]
# [{'label': 'anger', 'score': 0.9992081522941589}]
# [{'label': 'sadness', 'score': 0.9991851449012756}]
# [{'label': 'fear', 'score': 0.9984943866729736}]
# [{'label': 'fear', 'score': 0.9992432594299316}]
# [{'label': 'neutral', 'score': 0.9994118213653564}]
# [{'label': 'neutral', 'score': 0.9978815913200378}]
# [{'label': 'joy', 'score': 0.9744707942008972}]
# [{'label': 'anger', 'score': 0.43864375352859497}]
# [{'label': 'anger', 'score': 0.9938300251960754}]
# [{'label': 'neutral', 'score': 0.89720219373703}]
# [{'label': 'neutral', 'score': 0.951900839805603}]
# [{'label': 'fear', 'score': 0.9563746452331543}]
# [{'label': 'neutral', 'score': 0.7307679653167725}]
# [{'label': 'fear', 'score': 0.9969586133956909}]
# [{'label': 'fear', 'score': 0.8213794827461243}]
# [{'label': 'neutral', 'score': 0.9498924016952515}]
# [{'label': 'sadness', 'score': 0.9981046915054321}]
# [{'label': 'neutral', 'score': 0.9697460532188416}]
# [{'label': 'joy', 'score': 0.999015212059021}]
# [{'label': 'sadness', 'score': 0.9985594153404236}]
# [{'label': 'neutral', 'score': 0.9889771342277527}]
# [{'label': 'sadness', 'score': 0.9990875720977783}]
# [{'label': 'neutral', 'score': 0.9997672438621521}]
# [{'label': 'neutral', 'score': 0.9813372492790222}]
# [{'label': 'sadness', 'score': 0.36358198523521423}]
# [{'label': 'sadness', 'score': 0.9990453124046326}]
# [{'label': 'sadness', 'score': 0.8781552910804749}]
# [{'label': 'fear', 'score': 0.9811026453971863}]
# [{'label': 'fear', 'score': 0.9927886128425598}]
# [{'label': 'fear', 'score': 0.48275601863861084}]
# [{'label': 'fear', 'score': 0.9620870351791382}]
# [{'label': 'joy', 'score': 0.65435791015625}]
# [{'label': 'sadness', 'score': 0.7888410687446594}]
# [{'label': 'sadness', 'score': 0.9984768033027649}]
# [{'label': 'neutral', 'score': 0.9991703033447266}]
# [{'label': 'neutral', 'score': 0.9997301697731018}]
# [{'label': 'neutral', 'score': 0.9997403025627136}]
# [{'label': 'neutral', 'score': 0.9995711445808411}]
# [{'label': 'fear', 'score': 0.99847811460495}]
# [{'label': 'joy', 'score': 0.8590846061706543}]
# [{'label': 'neutral', 'score': 0.998618483543396}]
# [{'label': 'neutral', 'score': 0.9538098573684692}]
# [{'label': 'joy', 'score': 0.9782493114471436}]
# [{'label': 'anger', 'score': 0.6780521273612976}]
# [{'label': 'neutral', 'score': 0.9537867903709412}]
# [{'label': 'surprise', 'score': 0.9420247673988342}]
# [{'label': 'sadness', 'score': 0.9971237778663635}]
# [{'label': 'fear', 'score': 0.5639780759811401}]
# [{'label': 'sadness', 'score': 0.9991078972816467}]
# [{'label': 'sadness', 'score': 0.5707160234451294}]
# [{'label': 'sadness', 'score': 0.9990009665489197}]
# [{'label': 'sadness', 'score': 0.9992594122886658}]
# [{'label': 'neutral', 'score': 0.8748056292533875}]
# [{'label': 'neutral', 'score': 0.9615025520324707}]
# [{'label': 'neutral', 'score': 0.9997319579124451}]
# [{'label': 'anger', 'score': 0.9455814957618713}]
# [{'label': 'sadness', 'score': 0.9905285239219666}]
# [{'label': 'sadness', 'score': 0.9942024350166321}]
# [{'label': 'anger', 'score': 0.5461860299110413}]
# [{'label': 'neutral', 'score': 0.995142936706543}]
# [{'label': 'anger', 'score': 0.9559884071350098}]
# [{'label': 'joy', 'score': 0.9985186457633972}]
# [{'label': 'sadness', 'score': 0.9949797987937927}]
# [{'label': 'neutral', 'score': 0.9974325299263}]
# [{'label': 'sadness', 'score': 0.997215986251831}]
# [{'label': 'sadness', 'score': 0.9755640625953674}]
# [{'label': 'sadness', 'score': 0.9939873218536377}]
# [{'label': 'sadness', 'score': 0.9991008043289185}]
# [{'label': 'joy', 'score': 0.648472785949707}]
# [{'label': 'joy', 'score': 0.6982052326202393}]
# [{'label': 'neutral', 'score': 0.9987301230430603}]
# [{'label': 'joy', 'score': 0.998691737651825}]
# [{'label': 'neutral', 'score': 0.7730389833450317}]
# [{'label': 'neutral', 'score': 0.9997372031211853}]
# [{'label': 'joy', 'score': 0.9873328804969788}]
# [{'label': 'fear', 'score': 0.890781044960022}]
# [{'label': 'sadness', 'score': 0.9600653052330017}]
# [{'label': 'anger', 'score': 0.972919225692749}]
# [{'label': 'neutral', 'score': 0.9783312082290649}]
# [{'label': 'sadness', 'score': 0.9871954917907715}]
# [{'label': 'anger', 'score': 0.5252084732055664}]
# [{'label': 'neutral', 'score': 0.9997383952140808}]
# [{'label': 'joy', 'score': 0.7452449798583984}]
# [{'label': 'neutral', 'score': 0.9996370077133179}]
# [{'label': 'neutral', 'score': 0.8979580998420715}]
# [{'label': 'sadness', 'score': 0.9955108165740967}]
# [{'label': 'anger', 'score': 0.5933271646499634}]
# [{'label': 'neutral', 'score': 0.9996170997619629}]
# [{'label': 'neutral', 'score': 0.9995703101158142}]
# [{'label': 'sadness', 'score': 0.9830585718154907}]
# [{'label': 'neutral', 'score': 0.999358594417572}]
# [{'label': 'anger', 'score': 0.7005529403686523}]
# [{'label': 'anger', 'score': 0.8089746832847595}]
# [{'label': 'fear', 'score': 0.9911383986473083}]
# [{'label': 'neutral', 'score': 0.9885848164558411}]
# [{'label': 'sadness', 'score': 0.9355445504188538}]
# [{'label': 'neutral', 'score': 0.994631290435791}]
# [{'label': 'sadness', 'score': 0.9891647696495056}]
# [{'label': 'neutral', 'score': 0.9992541670799255}]
# [{'label': 'joy', 'score': 0.6145841479301453}]
# [{'label': 'sadness', 'score': 0.9990280866622925}]
# [{'label': 'neutral', 'score': 0.9997991919517517}]
# [{'label': 'joy', 'score': 0.9983593821525574}]
# [{'label': 'sadness', 'score': 0.9991033673286438}]
# [{'label': 'sadness', 'score': 0.9992170333862305}]
# [{'label': 'fear', 'score': 0.9976425766944885}]
# [{'label': 'fear', 'score': 0.9989314675331116}]
# [{'label': 'sadness', 'score': 0.7472200393676758}]
# [{'label': 'sadness', 'score': 0.9991405010223389}]
# [{'label': 'sadness', 'score': 0.9993150234222412}]
# [{'label': 'sadness', 'score': 0.9991294741630554}]
# [{'label': 'neutral', 'score': 0.998769223690033}]
# [{'label': 'sadness', 'score': 0.9909005165100098}]
# [{'label': 'sadness', 'score': 0.9986923336982727}]
# [{'label': 'neutral', 'score': 0.999660849571228}]
# [{'label': 'disgust', 'score': 0.9588723182678223}]
# [{'label': 'sadness', 'score': 0.9986832737922668}]
# [{'label': 'anger', 'score': 0.9977548718452454}]
# [{'label': 'neutral', 'score': 0.9995384216308594}]
# [{'label': 'neutral', 'score': 0.9997549653053284}]
# [{'label': 'neutral', 'score': 0.999697208404541}]
# [{'label': 'anger', 'score': 0.5395652055740356}]
# [{'label': 'neutral', 'score': 0.9997733235359192}]
# [{'label': 'neutral', 'score': 0.9997316002845764}]
# [{'label': 'neutral', 'score': 0.9980427026748657}]
# [{'label': 'neutral', 'score': 0.997885525226593}]
# [{'label': 'sadness', 'score': 0.9968841671943665}]
# [{'label': 'neutral', 'score': 0.997885525226593}]
# [{'label': 'neutral', 'score': 0.9997499585151672}]
# [{'label': 'joy', 'score': 0.85308438539505}]
# [{'label': 'sadness', 'score': 0.9977572560310364}]
# [{'label': 'neutral', 'score': 0.9997486472129822}]
# [{'label': 'fear', 'score': 0.9482917785644531}]
# [{'label': 'sadness', 'score': 0.9976736903190613}]
# [{'label': 'sadness', 'score': 0.9987905621528625}]
# [{'label': 'sadness', 'score': 0.9993098974227905}]
# [{'label': 'sadness', 'score': 0.9991251826286316}]
# [{'label': 'sadness', 'score': 0.999245285987854}]
# [{'label': 'sadness', 'score': 0.9944074153900146}]
# [{'label': 'sadness', 'score': 0.9944074153900146}]
# [{'label': 'neutral', 'score': 0.46874138712882996}]
# [{'label': 'neutral', 'score': 0.9996516704559326}]
# [{'label': 'joy', 'score': 0.8880375623703003}]
# [{'label': 'neutral', 'score': 0.9879580736160278}]
# [{'label': 'neutral', 'score': 0.99918133020401}]
# [{'label': 'neutral', 'score': 0.9987934827804565}]
# [{'label': 'neutral', 'score': 0.8676413297653198}]
# [{'label': 'sadness', 'score': 0.9968841671943665}]
# [{'label': 'neutral', 'score': 0.9907476902008057}]
# [{'label': 'sadness', 'score': 0.9982688426971436}]
# [{'label': 'joy', 'score': 0.9985314607620239}]
# [{'label': 'neutral', 'score': 0.9997803568840027}]
# [{'label': 'sadness', 'score': 0.9991507530212402}]
# [{'label': 'neutral', 'score': 0.9933564066886902}]
# [{'label': 'joy', 'score': 0.9983406066894531}]
# [{'label': 'neutral', 'score': 0.9997634291648865}]
# [{'label': 'neutral', 'score': 0.9556680917739868}]
# [{'label': 'anger', 'score': 0.9808930158615112}]
# [{'label': 'sadness', 'score': 0.8540868759155273}]
# [{'label': 'sadness', 'score': 0.9968841671943665}]
# [{'label': 'sadness', 'score': 0.9944074153900146}]
# [{'label': 'sadness', 'score': 0.9986737966537476}]
# [{'label': 'sadness', 'score': 0.6677282452583313}]
# [{'label': 'joy', 'score': 0.4514927864074707}]
# [{'label': 'neutral', 'score': 0.6803210973739624}]
# [{'label': 'joy', 'score': 0.7558889985084534}]
# [{'label': 'neutral', 'score': 0.9997126460075378}]
# [{'label': 'neutral', 'score': 0.9961769580841064}]
# [{'label': 'neutral', 'score': 0.9996194839477539}]
# [{'label': 'joy', 'score': 0.9990598559379578}]
# [{'label': 'joy', 'score': 0.9991610050201416}]
# [{'label': 'neutral', 'score': 0.9990277290344238}]
# [{'label': 'sadness', 'score': 0.9987384676933289}]
# [{'label': 'sadness', 'score': 0.9976159334182739}]
# [{'label': 'sadness', 'score': 0.9730739593505859}]
# [{'label': 'neutral', 'score': 0.9982870221138}]
# [{'label': 'sadness', 'score': 0.9987004995346069}]
# [{'label': 'sadness', 'score': 0.9992153644561768}]
# [{'label': 'sadness', 'score': 0.9993029832839966}]
# [{'label': 'anger', 'score': 0.49053364992141724}]
# [{'label': 'anger', 'score': 0.9190406799316406}]
# [{'label': 'anger', 'score': 0.7243971824645996}]
# [{'label': 'fear', 'score': 0.6766129732131958}]
# [{'label': 'sadness', 'score': 0.8738516569137573}]
# [{'label': 'neutral', 'score': 0.9990247488021851}]
# [{'label': 'sadness', 'score': 0.9993417859077454}]
# [{'label': 'sadness', 'score': 0.999062716960907}]
# [{'label': 'fear', 'score': 0.9740709066390991}]
# [{'label': 'neutral', 'score': 0.57709801197052}]
# [{'label': 'fear', 'score': 0.5988681316375732}]
# [{'label': 'fear', 'score': 0.9900918006896973}]
# [{'label': 'neutral', 'score': 0.6230424642562866}]
# [{'label': 'sadness', 'score': 0.4897722899913788}]
# [{'label': 'neutral', 'score': 0.5533503293991089}]
# [{'label': 'fear', 'score': 0.8702223896980286}]
# [{'label': 'neutral', 'score': 0.999549925327301}]
# [{'label': 'joy', 'score': 0.7910506725311279}]
# [{'label': 'anger', 'score': 0.965124249458313}]
# [{'label': 'fear', 'score': 0.519191563129425}]
# [{'label': 'neutral', 'score': 0.9985973238945007}]
# [{'label': 'neutral', 'score': 0.9994465708732605}]
# [{'label': 'fear', 'score': 0.9977096319198608}]
# [{'label': 'anger', 'score': 0.9990252256393433}]
# [{'label': 'fear', 'score': 0.9809426069259644}]
# [{'label': 'sadness', 'score': 0.9990348815917969}]
# [{'label': 'sadness', 'score': 0.7412499785423279}]
# [{'label': 'fear', 'score': 0.9977128505706787}]
# [{'label': 'neutral', 'score': 0.9934353828430176}]
# [{'label': 'neutral', 'score': 0.9989116191864014}]
# [{'label': 'neutral', 'score': 0.9898970127105713}]
# [{'label': 'sadness', 'score': 0.8191421031951904}]
# [{'label': 'neutral', 'score': 0.9819027185440063}]
# [{'label': 'joy', 'score': 0.9989663362503052}]
# [{'label': 'sadness', 'score': 0.999250590801239}]
# [{'label': 'neutral', 'score': 0.9939711689949036}]
# [{'label': 'neutral', 'score': 0.9997649788856506}]
# [{'label': 'fear', 'score': 0.9989738464355469}]
# [{'label': 'sadness', 'score': 0.689044713973999}]
# [{'label': 'sadness', 'score': 0.9992842078208923}]
# [{'label': 'sadness', 'score': 0.9984312653541565}]
# [{'label': 'sadness', 'score': 0.9968841671943665}]
# [{'label': 'sadness', 'score': 0.9968841671943665}]
# [{'label': 'fear', 'score': 0.46752434968948364}]
# [{'label': 'fear', 'score': 0.8272807002067566}]
# [{'label': 'neutral', 'score': 0.9994231462478638}]
# [{'label': 'neutral', 'score': 0.9996925592422485}]
# [{'label': 'neutral', 'score': 0.9885848164558411}]
# [{'label': 'sadness', 'score': 0.9976139068603516}]
# [{'label': 'sadness', 'score': 0.998660683631897}]
# [{'label': 'anger', 'score': 0.9115468263626099}]
# [{'label': 'neutral', 'score': 0.98055499792099}]
# [{'label': 'joy', 'score': 0.5077548623085022}]
# [{'label': 'sadness', 'score': 0.9872888326644897}]
# [{'label': 'sadness', 'score': 0.9992586970329285}]
# [{'label': 'neutral', 'score': 0.9987321496009827}]
# [{'label': 'neutral', 'score': 0.9913034439086914}]
# [{'label': 'anger', 'score': 0.9774970412254333}]
# [{'label': 'neutral', 'score': 0.9997413754463196}]
# [{'label': 'neutral', 'score': 0.8886718153953552}]
# [{'label': 'anger', 'score': 0.41408443450927734}]
# [{'label': 'fear', 'score': 0.9944325089454651}]
# [{'label': 'neutral', 'score': 0.9697628617286682}]
# [{'label': 'neutral', 'score': 0.8770444989204407}]
# [{'label': 'joy', 'score': 0.9959496259689331}]
# [{'label': 'anger', 'score': 0.9814774394035339}]
# [{'label': 'fear', 'score': 0.9363012909889221}]
# [{'label': 'fear', 'score': 0.9989872574806213}]
# [{'label': 'sadness', 'score': 0.8387829065322876}]
# [{'label': 'fear', 'score': 0.9769846200942993}]
# [{'label': 'joy', 'score': 0.9821116924285889}]
# [{'label': 'neutral', 'score': 0.9989116191864014}]
# [{'label': 'sadness', 'score': 0.9810671806335449}]
# [{'label': 'neutral', 'score': 0.8588003516197205}]
# [{'label': 'sadness', 'score': 0.9968841671943665}]
# [{'label': 'fear', 'score': 0.9985092282295227}]
# [{'label': 'neutral', 'score': 0.974919855594635}]
# [{'label': 'fear', 'score': 0.9982839226722717}]
# [{'label': 'fear', 'score': 0.9807284474372864}]
# [{'label': 'sadness', 'score': 0.9088813066482544}]
# [{'label': 'neutral', 'score': 0.9974592328071594}]
# [{'label': 'neutral', 'score': 0.982504665851593}]
# [{'label': 'neutral', 'score': 0.9994738698005676}]
# [{'label': 'anger', 'score': 0.8758746385574341}]
# [{'label': 'neutral', 'score': 0.9997405409812927}]
# [{'label': 'neutral', 'score': 0.9386343359947205}]
# [{'label': 'anger', 'score': 0.9976522326469421}]
# [{'label': 'anger', 'score': 0.7971253395080566}]
# [{'label': 'neutral', 'score': 0.9989492297172546}]
# [{'label': 'sadness', 'score': 0.4897722899913788}]
# [{'label': 'neutral', 'score': 0.999721348285675}]
# [{'label': 'neutral', 'score': 0.999750554561615}]
# [{'label': 'neutral', 'score': 0.9970073103904724}]
# [{'label': 'neutral', 'score': 0.9979971051216125}]
# [{'label': 'neutral', 'score': 0.9997014403343201}]
# [{'label': 'joy', 'score': 0.9984184503555298}]
# [{'label': 'neutral', 'score': 0.7408309578895569}]
# [{'label': 'neutral', 'score': 0.9995620846748352}]
# [{'label': 'sadness', 'score': 0.9986748695373535}]
# [{'label': 'neutral', 'score': 0.9996519088745117}]
# [{'label': 'neutral', 'score': 0.9979373216629028}]
# [{'label': 'sadness', 'score': 0.5758057832717896}]
# [{'label': 'joy', 'score': 0.7489873170852661}]
# [{'label': 'neutral', 'score': 0.9806187748908997}]
# [{'label': 'sadness', 'score': 0.9988229870796204}]
# [{'label': 'sadness', 'score': 0.9991762042045593}]
# [{'label': 'neutral', 'score': 0.9996546506881714}]
# [{'label': 'sadness', 'score': 0.9990971088409424}]
# [{'label': 'neutral', 'score': 0.9744988679885864}]
# [{'label': 'neutral', 'score': 0.9997196793556213}]
# [{'label': 'neutral', 'score': 0.9988325238227844}]
# [{'label': 'neutral', 'score': 0.8131165504455566}]
# [{'label': 'fear', 'score': 0.9798710942268372}]
# [{'label': 'fear', 'score': 0.9411882162094116}]
# [{'label': 'neutral', 'score': 0.9997336268424988}]
# [{'label': 'joy', 'score': 0.9986421465873718}]
# [{'label': 'neutral', 'score': 0.9470551013946533}]
# [{'label': 'fear', 'score': 0.9982636570930481}]
# [{'label': 'neutral', 'score': 0.9960565567016602}]
# [{'label': 'neutral', 'score': 0.99498450756073}]
# [{'label': 'neutral', 'score': 0.9960565567016602}]
# [{'label': 'sadness', 'score': 0.9980560541152954}]
# [{'label': 'neutral', 'score': 0.9960565567016602}]
# [{'label': 'fear', 'score': 0.8902333378791809}]
# [{'label': 'neutral', 'score': 0.8311729431152344}]
# [{'label': 'neutral', 'score': 0.8979580998420715}]
# [{'label': 'sadness', 'score': 0.9989377856254578}]
# [{'label': 'fear', 'score': 0.9985112547874451}]
# [{'label': 'joy', 'score': 0.998988687992096}]
# [{'label': 'joy', 'score': 0.9855659604072571}]
# [{'label': 'anger', 'score': 0.992146909236908}]
# [{'label': 'neutral', 'score': 0.7309715747833252}]
# [{'label': 'fear', 'score': 0.9936896562576294}]
# [{'label': 'neutral', 'score': 0.9987173080444336}]
# [{'label': 'neutral', 'score': 0.995968222618103}]
# [{'label': 'neutral', 'score': 0.9727869033813477}]
# [{'label': 'neutral', 'score': 0.811217725276947}]
# [{'label': 'joy', 'score': 0.7108959555625916}]
# [{'label': 'neutral', 'score': 0.9996392726898193}]
# [{'label': 'neutral', 'score': 0.9997071623802185}]
# [{'label': 'sadness', 'score': 0.9966164231300354}]
# [{'label': 'anger', 'score': 0.9942542910575867}]
# [{'label': 'fear', 'score': 0.829079806804657}]
# [{'label': 'disgust', 'score': 0.4806668758392334}]
# [{'label': 'fear', 'score': 0.998521625995636}]
# [{'label': 'fear', 'score': 0.9860296845436096}]
# [{'label': 'joy', 'score': 0.9792181253433228}]
# [{'label': 'fear', 'score': 0.9982035160064697}]
# [{'label': 'neutral', 'score': 0.9995493292808533}]
# [{'label': 'anger', 'score': 0.9977341890335083}]
# [{'label': 'fear', 'score': 0.6410313248634338}]
# [{'label': 'fear', 'score': 0.484485000371933}]
# [{'label': 'neutral', 'score': 0.9985139966011047}]
# [{'label': 'neutral', 'score': 0.9997281432151794}]
# [{'label': 'neutral', 'score': 0.9656698703765869}]
# [{'label': 'sadness', 'score': 0.9972502589225769}]
# [{'label': 'sadness', 'score': 0.9984232187271118}]
# [{'label': 'neutral', 'score': 0.9989116191864014}]
# [{'label': 'sadness', 'score': 0.9989238381385803}]
# [{'label': 'sadness', 'score': 0.9993194341659546}]
# [{'label': 'neutral', 'score': 0.9985494017601013}]
# [{'label': 'joy', 'score': 0.998629093170166}]
# [{'label': 'joy', 'score': 0.6609439849853516}]
# [{'label': 'neutral', 'score': 0.9996210336685181}]
# [{'label': 'neutral', 'score': 0.9990376234054565}]
# [{'label': 'sadness', 'score': 0.7688036561012268}]
# [{'label': 'neutral', 'score': 0.9996238946914673}]
# [{'label': 'neutral', 'score': 0.9993906021118164}]
# [{'label': 'sadness', 'score': 0.9981959462165833}]
# [{'label': 'joy', 'score': 0.9842315912246704}]
# [{'label': 'neutral', 'score': 0.9993212223052979}]
# [{'label': 'neutral', 'score': 0.6853617429733276}]
# [{'label': 'fear', 'score': 0.654991626739502}]
# [{'label': 'fear', 'score': 0.9944891929626465}]
# [{'label': 'fear', 'score': 0.9944891929626465}]
# [{'label': 'fear', 'score': 0.9971601963043213}]
# [{'label': 'fear', 'score': 0.8813719153404236}]
# [{'label': 'sadness', 'score': 0.8338145613670349}]
# [{'label': 'anger', 'score': 0.8165320754051208}]
# [{'label': 'fear', 'score': 0.9981510043144226}]
# [{'label': 'sadness', 'score': 0.44666919112205505}]
# [{'label': 'sadness', 'score': 0.9583737254142761}]
# [{'label': 'sadness', 'score': 0.37701088190078735}]
# [{'label': 'fear', 'score': 0.9981265664100647}]
# [{'label': 'neutral', 'score': 0.9996073842048645}]
# [{'label': 'neutral', 'score': 0.9933404326438904}]
# [{'label': 'joy', 'score': 0.9964960217475891}]
# [{'label': 'sadness', 'score': 0.9504055380821228}]
# [{'label': 'joy', 'score': 0.9987117052078247}]
# [{'label': 'neutral', 'score': 0.9997398257255554}]
# [{'label': 'neutral', 'score': 0.999756395816803}]
# [{'label': 'neutral', 'score': 0.9978815913200378}]
# [{'label': 'neutral', 'score': 0.9978815913200378}]
# [{'label': 'neutral', 'score': 0.997885525226593}]
# [{'label': 'joy', 'score': 0.9979693293571472}]
# [{'label': 'sadness', 'score': 0.9984466433525085}]
# [{'label': 'neutral', 'score': 0.9739780426025391}]
# [{'label': 'fear', 'score': 0.9310960173606873}]
# [{'label': 'neutral', 'score': 0.9956484436988831}]
# [{'label': 'neutral', 'score': 0.9835363626480103}]
# [{'label': 'neutral', 'score': 0.999512791633606}]
# [{'label': 'anger', 'score': 0.9954504370689392}]
# [{'label': 'neutral', 'score': 0.5926935076713562}]
# [{'label': 'neutral', 'score': 0.9977917671203613}]
# [{'label': 'neutral', 'score': 0.8833644390106201}]
# [{'label': 'neutral', 'score': 0.9991059899330139}]
# [{'label': 'neutral', 'score': 0.999570906162262}]
# [{'label': 'fear', 'score': 0.9987909197807312}]
# [{'label': 'neutral', 'score': 0.9995760321617126}]
# [{'label': 'neutral', 'score': 0.9949272871017456}]
# [{'label': 'neutral', 'score': 0.9996603727340698}]
# [{'label': 'sadness', 'score': 0.9944074153900146}]
# [{'label': 'neutral', 'score': 0.7823013663291931}]
# [{'label': 'sadness', 'score': 0.9944074153900146}]
# [{'label': 'neutral', 'score': 0.9994120597839355}]
# [{'label': 'sadness', 'score': 0.9944074153900146}]
# [{'label': 'neutral', 'score': 0.9998001456260681}]
# [{'label': 'joy', 'score': 0.9981526732444763}]
# [{'label': 'neutral', 'score': 0.9959583878517151}]
# [{'label': 'neutral', 'score': 0.9973553419113159}]
# [{'label': 'neutral', 'score': 0.9894715547561646}]
# [{'label': 'anger', 'score': 0.7415305972099304}]
# [{'label': 'sadness', 'score': 0.5281626582145691}]
# [{'label': 'fear', 'score': 0.9350744485855103}]
# [{'label': 'neutral', 'score': 0.9996888637542725}]
# [{'label': 'joy', 'score': 0.9713969230651855}]
# [{'label': 'neutral', 'score': 0.9754035472869873}]
# [{'label': 'sadness', 'score': 0.9981006979942322}]
# [{'label': 'joy', 'score': 0.9988648891448975}]
# [{'label': 'neutral', 'score': 0.9959403276443481}]
# [{'label': 'fear', 'score': 0.8317118287086487}]
# [{'label': 'fear', 'score': 0.9891830682754517}]
# [{'label': 'fear', 'score': 0.9509291052818298}]
# [{'label': 'joy', 'score': 0.9749064445495605}]
# [{'label': 'neutral', 'score': 0.9996176958084106}]
# [{'label': 'fear', 'score': 0.9185013771057129}]
# [{'label': 'neutral', 'score': 0.9990894794464111}]
# [{'label': 'neutral', 'score': 0.997885525226593}]
# [{'label': 'neutral', 'score': 0.997885525226593}]
# [{'label': 'sadness', 'score': 0.5311974287033081}]
# [{'label': 'neutral', 'score': 0.6693276762962341}]
# [{'label': 'joy', 'score': 0.7471152544021606}]
# [{'label': 'sadness', 'score': 0.9943481087684631}]
# [{'label': 'neutral', 'score': 0.9997138381004333}]
# [{'label': 'neutral', 'score': 0.9885848164558411}]
# [{'label': 'joy', 'score': 0.9992173910140991}]
# [{'label': 'fear', 'score': 0.9795661568641663}]
# [{'label': 'anger', 'score': 0.7805835008621216}]
# [{'label': 'joy', 'score': 0.9533381462097168}]
# [{'label': 'fear', 'score': 0.9751548767089844}]
# [{'label': 'fear', 'score': 0.994976282119751}]
# [{'label': 'neutral', 'score': 0.7825466394424438}]
# [{'label': 'fear', 'score': 0.649598240852356}]
# [{'label': 'neutral', 'score': 0.9903945326805115}]
# [{'label': 'neutral', 'score': 0.9994404911994934}]
# [{'label': 'neutral', 'score': 0.9989211559295654}]
# [{'label': 'neutral', 'score': 0.9990299940109253}]
# [{'label': 'neutral', 'score': 0.9988188147544861}]
# [{'label': 'disgust', 'score': 0.8501020669937134}]
# [{'label': 'neutral', 'score': 0.49421465396881104}]
# [{'label': 'neutral', 'score': 0.9989116191864014}]
# [{'label': 'neutral', 'score': 0.9244716763496399}]
# [{'label': 'sadness', 'score': 0.9969238638877869}]
# [{'label': 'sadness', 'score': 0.9980366826057434}]
# [{'label': 'neutral', 'score': 0.6033608317375183}]
# [{'label': 'neutral', 'score': 0.9751968383789062}]
# [{'label': 'neutral', 'score': 0.9975632429122925}]
# [{'label': 'sadness', 'score': 0.8875251412391663}]
# [{'label': 'fear', 'score': 0.9989319443702698}]
# [{'label': 'neutral', 'score': 0.7388808131217957}]
# [{'label': 'sadness', 'score': 0.5703433156013489}]
# [{'label': 'surprise', 'score': 0.9944926500320435}]
# [{'label': 'neutral', 'score': 0.9993221759796143}]
# [{'label': 'joy', 'score': 0.9976224303245544}]
# [{'label': 'neutral', 'score': 0.4183560907840729}]
# [{'label': 'surprise', 'score': 0.9549026489257812}]
# [{'label': 'fear', 'score': 0.9613120555877686}]
# [{'label': 'fear', 'score': 0.998713493347168}]
# [{'label': 'neutral', 'score': 0.9990575909614563}]
# [{'label': 'neutral', 'score': 0.9997237324714661}]
# [{'label': 'neutral', 'score': 0.9974310994148254}]
# [{'label': 'sadness', 'score': 0.7972328066825867}]
# [{'label': 'neutral', 'score': 0.9003787040710449}]
# [{'label': 'sadness', 'score': 0.9694404602050781}]
# [{'label': 'sadness', 'score': 0.9984530210494995}]
# [{'label': 'fear', 'score': 0.5797765851020813}]
# [{'label': 'sadness', 'score': 0.7158331871032715}]
# [{'label': 'sadness', 'score': 0.9978311657905579}]
# [{'label': 'sadness', 'score': 0.999305009841919}]
# [{'label': 'joy', 'score': 0.997885525226593}]
# [{'label': 'anger', 'score': 0.4584042429924011}]
# [{'label': 'neutral', 'score': 0.5306289792060852}]
# [{'label': 'neutral', 'score': 0.8365477323532104}]
# [{'label': 'disgust', 'score': 0.7768380045890808}]
# [{'label': 'fear', 'score': 0.9753026962280273}]
# [{'label': 'neutral', 'score': 0.999754011631012}]
# [{'label': 'neutral', 'score': 0.9991311430931091}]
# [{'label': 'neutral', 'score': 0.9477401375770569}]
# [{'label': 'neutral', 'score': 0.9972902536392212}]
# [{'label': 'neutral', 'score': 0.9758457541465759}]
# [{'label': 'fear', 'score': 0.973901629447937}]
# [{'label': 'neutral', 'score': 0.9996813535690308}]
# [{'label': 'neutral', 'score': 0.9926409125328064}]
# [{'label': 'neutral', 'score': 0.9989171028137207}]
# [{'label': 'sadness', 'score': 0.7321659326553345}]
# [{'label': 'sadness', 'score': 0.9137434363365173}]
# [{'label': 'joy', 'score': 0.9444534182548523}]
# [{'label': 'sadness', 'score': 0.8273969888687134}]
# [{'label': 'anger', 'score': 0.9987987279891968}]
# [{'label': 'anger', 'score': 0.9989911913871765}]
# [{'label': 'anger', 'score': 0.8816918134689331}]
# [{'label': 'neutral', 'score': 0.9996868371963501}]
# [{'label': 'sadness', 'score': 0.9991779923439026}]
# [{'label': 'neutral', 'score': 0.9987792372703552}]
# [{'label': 'neutral', 'score': 0.9997826218605042}]
# [{'label': 'joy', 'score': 0.8030961155891418}]
# [{'label': 'neutral', 'score': 0.9996532201766968}]
# [{'label': 'fear', 'score': 0.980678915977478}]
# [{'label': 'anger', 'score': 0.6376514434814453}]
# [{'label': 'anger', 'score': 0.9977327585220337}]
# [{'label': 'neutral', 'score': 0.995941698551178}]
# [{'label': 'neutral', 'score': 0.996306300163269}]
# [{'label': 'joy', 'score': 0.6667242646217346}]
# [{'label': 'neutral', 'score': 0.9994922876358032}]
# [{'label': 'neutral', 'score': 0.9971511960029602}]
# [{'label': 'sadness', 'score': 0.997319757938385}]
# [{'label': 'surprise', 'score': 0.6219260692596436}]
# [{'label': 'fear', 'score': 0.999076247215271}]
# [{'label': 'neutral', 'score': 0.9996013045310974}]
# [{'label': 'neutral', 'score': 0.9993597865104675}]
# [{'label': 'neutral', 'score': 0.942125678062439}]
# [{'label': 'neutral', 'score': 0.8979580998420715}]
# [{'label': 'neutral', 'score': 0.9966711401939392}]
# [{'label': 'neutral', 'score': 0.9997640252113342}]
# [{'label': 'sadness', 'score': 0.8385382890701294}]
# [{'label': 'sadness', 'score': 0.9988597631454468}]
# [{'label': 'joy', 'score': 0.9988137483596802}]
# [{'label': 'neutral', 'score': 0.9996032118797302}]
# [{'label': 'joy', 'score': 0.9146450161933899}]
# [{'label': 'fear', 'score': 0.9988732933998108}]
# [{'label': 'joy', 'score': 0.6229768991470337}]
# [{'label': 'neutral', 'score': 0.740115225315094}]
# [{'label': 'sadness', 'score': 0.9991027116775513}]
# [{'label': 'fear', 'score': 0.9992215633392334}]
# [{'label': 'fear', 'score': 0.8461872339248657}]
# [{'label': 'fear', 'score': 0.9629424810409546}]
# [{'label': 'sadness', 'score': 0.9913120865821838}]
# [{'label': 'sadness', 'score': 0.9987881779670715}]
# [{'label': 'sadness', 'score': 0.9969056248664856}]
# [{'label': 'sadness', 'score': 0.9968841671943665}]
# [{'label': 'neutral', 'score': 0.999261200428009}]
# [{'label': 'anger', 'score': 0.4157477617263794}]
# [{'label': 'neutral', 'score': 0.9987323880195618}]
# [{'label': 'anger', 'score': 0.8588261008262634}]
# [{'label': 'neutral', 'score': 0.9997686743736267}]
# [{'label': 'joy', 'score': 0.9749064445495605}]
# [{'label': 'sadness', 'score': 0.9990185499191284}]
# [{'label': 'disgust', 'score': 0.9980379939079285}]
# [{'label': 'sadness', 'score': 0.9992170333862305}]
# [{'label': 'neutral', 'score': 0.941556453704834}]
# [{'label': 'surprise', 'score': 0.6419283151626587}]
# [{'label': 'anger', 'score': 0.5591281652450562}]
# [{'label': 'fear', 'score': 0.9933484196662903}]
# [{'label': 'neutral', 'score': 0.9230466485023499}]
# [{'label': 'neutral', 'score': 0.9994809031486511}]
# [{'label': 'neutral', 'score': 0.9940118193626404}]
# [{'label': 'sadness', 'score': 0.5062907934188843}]
# [{'label': 'neutral', 'score': 0.9997708201408386}]
# [{'label': 'fear', 'score': 0.9747938513755798}]
# [{'label': 'neutral', 'score': 0.99972003698349}]
# [{'label': 'neutral', 'score': 0.9792183041572571}]
# [{'label': 'neutral', 'score': 0.9990233182907104}]
# [{'label': 'neutral', 'score': 0.9982219338417053}]
# [{'label': 'neutral', 'score': 0.9839581251144409}]
# [{'label': 'neutral', 'score': 0.9993330836296082}]
# [{'label': 'sadness', 'score': 0.9984545707702637}]
# [{'label': 'sadness', 'score': 0.9902310967445374}]
# [{'label': 'sadness', 'score': 0.9865612387657166}]
# [{'label': 'neutral', 'score': 0.9949774146080017}]
# [{'label': 'neutral', 'score': 0.9995500445365906}]
# [{'label': 'neutral', 'score': 0.9993929862976074}]
# [{'label': 'neutral', 'score': 0.9995433688163757}]
# [{'label': 'surprise', 'score': 0.9810866713523865}]
# [{'label': 'surprise', 'score': 0.9534111618995667}]
# [{'label': 'sadness', 'score': 0.9990484118461609}]
# [{'label': 'neutral', 'score': 0.9813698530197144}]
# [{'label': 'sadness', 'score': 0.9991059899330139}]
# [{'label': 'joy', 'score': 0.986598014831543}]
# [{'label': 'neutral', 'score': 0.543050229549408}]
# [{'label': 'joy', 'score': 0.9988603591918945}]
# [{'label': 'joy', 'score': 0.9988178610801697}]
# [{'label': 'anger', 'score': 0.9795756936073303}]
# [{'label': 'neutral', 'score': 0.9991181492805481}]
# [{'label': 'joy', 'score': 0.9967020153999329}]
# [{'label': 'sadness', 'score': 0.746454119682312}]
# [{'label': 'neutral', 'score': 0.9996966123580933}]
# [{'label': 'neutral', 'score': 0.9977372884750366}]
# [{'label': 'neutral', 'score': 0.9997510313987732}]
# [{'label': 'neutral', 'score': 0.9071451425552368}]
# [{'label': 'neutral', 'score': 0.998600423336029}]
# [{'label': 'neutral', 'score': 0.9995689988136292}]
# [{'label': 'neutral', 'score': 0.6786923408508301}]
# [{'label': 'neutral', 'score': 0.9956458210945129}]
# [{'label': 'joy', 'score': 0.5443477034568787}]
# [{'label': 'neutral', 'score': 0.9900001883506775}]
# [{'label': 'neutral', 'score': 0.9995772242546082}]
# [{'label': 'neutral', 'score': 0.9995904564857483}]
# [{'label': 'neutral', 'score': 0.9996054768562317}]
# [{'label': 'neutral', 'score': 0.580442488193512}]
# [{'label': 'neutral', 'score': 0.9954364895820618}]
# [{'label': 'neutral', 'score': 0.9936037659645081}]
# [{'label': 'neutral', 'score': 0.5134460926055908}]
# [{'label': 'neutral', 'score': 0.7884764671325684}]
# [{'label': 'neutral', 'score': 0.9964540004730225}]
# [{'label': 'anger', 'score': 0.9749680161476135}]
# [{'label': 'surprise', 'score': 0.9794529676437378}]
# [{'label': 'neutral', 'score': 0.9995971322059631}]
# [{'label': 'fear', 'score': 0.9118626117706299}]
# [{'label': 'neutral', 'score': 0.9997314810752869}]
# [{'label': 'anger', 'score': 0.9982998967170715}]
# [{'label': 'neutral', 'score': 0.9978815913200378}]
# [{'label': 'neutral', 'score': 0.9822803139686584}]
# [{'label': 'neutral', 'score': 0.9986521601676941}]
# [{'label': 'joy', 'score': 0.9979580640792847}]
# [{'label': 'joy', 'score': 0.7654534578323364}]
# [{'label': 'neutral', 'score': 0.9992276430130005}]
# [{'label': 'surprise', 'score': 0.5668818950653076}]
# [{'label': 'anger', 'score': 0.817930281162262}]
# [{'label': 'anger', 'score': 0.9977263808250427}]
# [{'label': 'sadness', 'score': 0.9968841671943665}]
# [{'label': 'neutral', 'score': 0.8588003516197205}]
# [{'label': 'joy', 'score': 0.9989118576049805}]
# [{'label': 'neutral', 'score': 0.9992045760154724}]
# [{'label': 'neutral', 'score': 0.9989835619926453}]
# [{'label': 'neutral', 'score': 0.9996553659439087}]
# [{'label': 'joy', 'score': 0.9980216026306152}]
# [{'label': 'neutral', 'score': 0.9957180619239807}]
# [{'label': 'sadness', 'score': 0.9992157220840454}]
# [{'label': 'neutral', 'score': 0.7765423655509949}]
# [{'label': 'anger', 'score': 0.43901872634887695}]
# [{'label': 'anger', 'score': 0.9967890977859497}]
# [{'label': 'joy', 'score': 0.9902708530426025}]
# [{'label': 'sadness', 'score': 0.9373760223388672}]
# [{'label': 'sadness', 'score': 0.9968841671943665}]
# [{'label': 'neutral', 'score': 0.8588003516197205}]
# [{'label': 'fear', 'score': 0.9968354105949402}]
# [{'label': 'neutral', 'score': 0.9994268417358398}]
# [{'label': 'anger', 'score': 0.5800482630729675}]
# [{'label': 'joy', 'score': 0.9982185959815979}]
# [{'label': 'sadness', 'score': 0.5317338109016418}]
# [{'label': 'fear', 'score': 0.9629424810409546}]
# [{'label': 'anger', 'score': 0.8329792022705078}]
# [{'label': 'fear', 'score': 0.5633144378662109}]
# [{'label': 'neutral', 'score': 0.6205119490623474}]
# [{'label': 'fear', 'score': 0.8779918551445007}]
# [{'label': 'neutral', 'score': 0.9227340221405029}]
# [{'label': 'neutral', 'score': 0.8188130855560303}]
# [{'label': 'anger', 'score': 0.4084421992301941}]
# [{'label': 'disgust', 'score': 0.9701541066169739}]
# [{'label': 'neutral', 'score': 0.9965295195579529}]
# [{'label': 'neutral', 'score': 0.8014910221099854}]
# [{'label': 'neutral', 'score': 0.9963169097900391}]
# ...
# [{'label': 'neutral', 'score': 0.9991394281387329}]
# [{'label': 'sadness', 'score': 0.999240517616272}]
# [{'label': 'sadness', 'score': 0.9989591836929321}]
# [{'label': 'anger', 'score': 0.8828426003456116}]
# [{'label': 'joy', 'score': 0.9923273921012878}]
# [{'label': 'neutral', 'score': 0.9962887763977051}]
# [{'label': 'anger', 'score': 0.4166789948940277}]
# [{'label': 'sadness', 'score': 0.7142724990844727}]
# [{'label': 'sadness', 'score': 0.9992596507072449}]
# [{'label': 'sadness', 'score': 0.9834781289100647}]
# [{'label': 'fear', 'score': 0.8753994703292847}]
# [{'label': 'neutral', 'score': 0.9983226656913757}]
# [{'label': 'neutral', 'score': 0.9994945526123047}]
# [{'label': 'neutral', 'score': 0.9984074234962463}]
# [{'label': 'neutral', 'score': 0.9997618794441223}]
# [{'label': 'neutral', 'score': 0.9923644065856934}]
# [{'label': 'neutral', 'score': 0.9920670986175537}]
# [{'label': 'neutral', 'score': 0.9990890026092529}]
# [{'label': 'anger', 'score': 0.973483681678772}]
# [{'label': 'sadness', 'score': 0.9813421368598938}]
# [{'label': 'fear', 'score': 0.9966699481010437}]
# [{'label': 'neutral', 'score': 0.9990509152412415}]
# [{'label': 'neutral', 'score': 0.9959185719490051}]
# [{'label': 'neutral', 'score': 0.9997040629386902}]
# [{'label': 'neutral', 'score': 0.9994046688079834}]
# [{'label': 'neutral', 'score': 0.9995978474617004}]
# [{'label': 'neutral', 'score': 0.9972283244132996}]
# [{'label': 'neutral', 'score': 0.9779446721076965}]
# [{'label': 'neutral', 'score': 0.9994202852249146}]
# [{'label': 'sadness', 'score': 0.9984425902366638}]
# [{'label': 'anger', 'score': 0.9576305747032166}]
# [{'label': 'sadness', 'score': 0.9935100674629211}]
# [{'label': 'fear', 'score': 0.9529805183410645}]
# [{'label': 'sadness', 'score': 0.9952167272567749}]
# [{'label': 'neutral', 'score': 0.9997127652168274}]
# [{'label': 'joy', 'score': 0.997265100479126}]
# [{'label': 'fear', 'score': 0.9987751841545105}]
# [{'label': 'fear', 'score': 0.9862855076789856}]
# [{'label': 'fear', 'score': 0.9497266411781311}]
# [{'label': 'joy', 'score': 0.9988052845001221}]
# [{'label': 'anger', 'score': 0.9973638653755188}]
# [{'label': 'neutral', 'score': 0.5763236880302429}]
# [{'label': 'fear', 'score': 0.6552924513816833}]
# [{'label': 'fear', 'score': 0.8677816987037659}]
# [{'label': 'joy', 'score': 0.9668799638748169}]
# [{'label': 'sadness', 'score': 0.9362428784370422}]
# [{'label': 'sadness', 'score': 0.9362428784370422}]
# [{'label': 'fear', 'score': 0.9992513060569763}]
# [{'label': 'neutral', 'score': 0.9747196435928345}]
# [{'label': 'neutral', 'score': 0.9995511174201965}]
# [{'label': 'joy', 'score': 0.8419609069824219}]
# [{'label': 'fear', 'score': 0.41263049840927124}]
# [{'label': 'neutral', 'score': 0.9763131141662598}]
# [{'label': 'fear', 'score': 0.8739609122276306}]
# [{'label': 'neutral', 'score': 0.9763345718383789}]
# [{'label': 'neutral', 'score': 0.9890047907829285}]
# [{'label': 'anger', 'score': 0.7952880263328552}]
# [{'label': 'sadness', 'score': 0.9875652194023132}]
# [{'label': 'neutral', 'score': 0.9982641339302063}]
# [{'label': 'neutral', 'score': 0.9994990825653076}]
# [{'label': 'neutral', 'score': 0.6290907859802246}]
# [{'label': 'joy', 'score': 0.9990686774253845}]
# [{'label': 'fear', 'score': 0.9987794756889343}]
# [{'label': 'joy', 'score': 0.9918035268783569}]
# [{'label': 'neutral', 'score': 0.9996023774147034}]
# [{'label': 'anger', 'score': 0.9962384700775146}]
# [{'label': 'neutral', 'score': 0.9992006421089172}]
# [{'label': 'joy', 'score': 0.9990758895874023}]
# [{'label': 'neutral', 'score': 0.9976648092269897}]
# [{'label': 'joy', 'score': 0.9598240852355957}]
# [{'label': 'fear', 'score': 0.9907559752464294}]
# [{'label': 'neutral', 'score': 0.9997633099555969}]
# [{'label': 'neutral', 'score': 0.950094997882843}]
# [{'label': 'sadness', 'score': 0.9989994168281555}]
# [{'label': 'neutral', 'score': 0.9989221096038818}]
# [{'label': 'sadness', 'score': 0.9886536002159119}]
# [{'label': 'neutral', 'score': 0.9975548386573792}]
# [{'label': 'sadness', 'score': 0.9752261638641357}]
# [{'label': 'neutral', 'score': 0.9996803998947144}]
# [{'label': 'joy', 'score': 0.9983945488929749}]
# [{'label': 'joy', 'score': 0.894434928894043}]
# [{'label': 'fear', 'score': 0.9971606731414795}]
# [{'label': 'neutral', 'score': 0.9785849452018738}]
# [{'label': 'neutral', 'score': 0.9923043847084045}]
# [{'label': 'neutral', 'score': 0.9972450733184814}]
# [{'label': 'neutral', 'score': 0.9977561831474304}]
# [{'label': 'neutral', 'score': 0.9756351709365845}]
# [{'label': 'disgust', 'score': 0.8821765780448914}]
# [{'label': 'sadness', 'score': 0.998019814491272}]
# [{'label': 'sadness', 'score': 0.9954133629798889}]
# [{'label': 'neutral', 'score': 0.999653697013855}]
# [{'label': 'neutral', 'score': 0.9866482615470886}]
# [{'label': 'sadness', 'score': 0.9607061147689819}]
# [{'label': 'sadness', 'score': 0.9824156165122986}]
# [{'label': 'joy', 'score': 0.9934129118919373}]
# [{'label': 'neutral', 'score': 0.950790524482727}]
# [{'label': 'neutral', 'score': 0.9978839755058289}]
# [{'label': 'neutral', 'score': 0.9268971085548401}]
# [{'label': 'joy', 'score': 0.9219867587089539}]
# [{'label': 'joy', 'score': 0.937757670879364}]
# [{'label': 'neutral', 'score': 0.9997382760047913}]
# [{'label': 'surprise', 'score': 0.4989404082298279}]
# [{'label': 'joy', 'score': 0.9977966547012329}]
# [{'label': 'sadness', 'score': 0.985211968421936}]
# [{'label': 'anger', 'score': 0.6601678133010864}]
# [{'label': 'neutral', 'score': 0.9997648596763611}]
# [{'label': 'joy', 'score': 0.6229768991470337}]
# [{'label': 'neutral', 'score': 0.9996170997619629}]
# [{'label': 'sadness', 'score': 0.9993177652359009}]
# [{'label': 'surprise', 'score': 0.7323554754257202}]
# [{'label': 'joy', 'score': 0.9047672152519226}]
# [{'label': 'neutral', 'score': 0.9965630173683167}]
# [{'label': 'neutral', 'score': 0.9960616230964661}]
# [{'label': 'neutral', 'score': 0.9997346997261047}]
# [{'label': 'sadness', 'score': 0.9980541467666626}]
# [{'label': 'disgust', 'score': 0.5536084771156311}]
# [{'label': 'joy', 'score': 0.9309772849082947}]
# [{'label': 'neutral', 'score': 0.6570588946342468}]
# [{'label': 'fear', 'score': 0.9806659817695618}]
# [{'label': 'sadness', 'score': 0.9943179488182068}]
# [{'label': 'neutral', 'score': 0.9997548460960388}]
# [{'label': 'joy', 'score': 0.8612934350967407}]
# [{'label': 'sadness', 'score': 0.9984331727027893}]
# [{'label': 'fear', 'score': 0.5797765851020813}]
# [{'label': 'neutral', 'score': 0.9990946054458618}]
# [{'label': 'neutral', 'score': 0.8248481154441833}]
# [{'label': 'neutral', 'score': 0.9506715536117554}]
# [{'label': 'neutral', 'score': 0.9939828515052795}]
# [{'label': 'neutral', 'score': 0.9987039566040039}]
# [{'label': 'sadness', 'score': 0.998213529586792}]
# [{'label': 'fear', 'score': 0.9923413991928101}]
# [{'label': 'fear', 'score': 0.8968321084976196}]
# [{'label': 'fear', 'score': 0.9957824945449829}]
# [{'label': 'fear', 'score': 0.878995954990387}]
# [{'label': 'fear', 'score': 0.9971328973770142}]
# [{'label': 'fear', 'score': 0.9944288730621338}]
# [{'label': 'fear', 'score': 0.9143248796463013}]
# [{'label': 'neutral', 'score': 0.9670171737670898}]
# [{'label': 'fear', 'score': 0.9712346196174622}]
# [{'label': 'sadness', 'score': 0.9979543685913086}]
# [{'label': 'fear', 'score': 0.990944504737854}]
# [{'label': 'neutral', 'score': 0.9975778460502625}]
# [{'label': 'sadness', 'score': 0.9926062822341919}]
# [{'label': 'sadness', 'score': 0.7560478448867798}]
# [{'label': 'neutral', 'score': 0.9991831183433533}]
# [{'label': 'neutral', 'score': 0.9990779161453247}]
# [{'label': 'neutral', 'score': 0.9957414865493774}]
# [{'label': 'sadness', 'score': 0.9987201690673828}]
# [{'label': 'sadness', 'score': 0.9992944002151489}]
# [{'label': 'sadness', 'score': 0.9919658899307251}]
# [{'label': 'fear', 'score': 0.998489260673523}]
# [{'label': 'sadness', 'score': 0.9088813066482544}]
# [{'label': 'sadness', 'score': 0.9992170333862305}]
# [{'label': 'neutral', 'score': 0.9996992349624634}]
# [{'label': 'sadness', 'score': 0.5359644293785095}]
# [{'label': 'neutral', 'score': 0.4941410720348358}]
# [{'label': 'neutral', 'score': 0.9994214773178101}]
# [{'label': 'neutral', 'score': 0.9993853569030762}]
# [{'label': 'neutral', 'score': 0.9885848164558411}]
# [{'label': 'sadness', 'score': 0.9944074153900146}]
# [{'label': 'sadness', 'score': 0.9961017370223999}]
# [{'label': 'joy', 'score': 0.9986779093742371}]
# [{'label': 'joy', 'score': 0.9983100891113281}]
# [{'label': 'sadness', 'score': 0.9499269127845764}]
# [{'label': 'joy', 'score': 0.9985464215278625}]
# [{'label': 'sadness', 'score': 0.927085280418396}]
# [{'label': 'sadness', 'score': 0.9747276902198792}]
# [{'label': 'neutral', 'score': 0.9996623992919922}]
# [{'label': 'sadness', 'score': 0.9987192153930664}]
# [{'label': 'neutral', 'score': 0.9957821369171143}]
# [{'label': 'fear', 'score': 0.7756739258766174}]
# [{'label': 'neutral', 'score': 0.9978815913200378}]
# [{'label': 'neutral', 'score': 0.9996777772903442}]
# [{'label': 'neutral', 'score': 0.9937012195587158}]
# [{'label': 'sadness', 'score': 0.9932399988174438}]
# [{'label': 'joy', 'score': 0.9986057877540588}]
# [{'label': 'neutral', 'score': 0.997885525226593}]
# [{'label': 'neutral', 'score': 0.8588003516197205}]
# [{'label': 'neutral', 'score': 0.9991703033447266}]
# [{'label': 'neutral', 'score': 0.9995085000991821}]
# [{'label': 'neutral', 'score': 0.9878154993057251}]
# [{'label': 'sadness', 'score': 0.9523161053657532}]
# [{'label': 'joy', 'score': 0.9991714954376221}]
# [{'label': 'fear', 'score': 0.682265043258667}]
# [{'label': 'neutral', 'score': 0.4807722866535187}]
# [{'label': 'anger', 'score': 0.8837161064147949}]
# [{'label': 'sadness', 'score': 0.9975706934928894}]
# [{'label': 'fear', 'score': 0.9982873797416687}]
# [{'label': 'joy', 'score': 0.999055802822113}]
# [{'label': 'sadness', 'score': 0.9972520470619202}]
# [{'label': 'neutral', 'score': 0.9993322491645813}]
# [{'label': 'sadness', 'score': 0.9988523721694946}]
# [{'label': 'neutral', 'score': 0.9994114637374878}]
# [{'label': 'neutral', 'score': 0.9996483325958252}]
# [{'label': 'neutral', 'score': 0.8936712741851807}]
# [{'label': 'sadness', 'score': 0.6508634090423584}]
# [{'label': 'neutral', 'score': 0.9995169639587402}]
# [{'label': 'neutral', 'score': 0.9996065497398376}]
# [{'label': 'neutral', 'score': 0.9912095069885254}]
# [{'label': 'fear', 'score': 0.9910719990730286}]
# [{'label': 'fear', 'score': 0.9981663823127747}]
# [{'label': 'neutral', 'score': 0.9990379810333252}]
# [{'label': 'sadness', 'score': 0.9698560833930969}]
# [{'label': 'fear', 'score': 0.9809735417366028}]
# [{'label': 'joy', 'score': 0.8352423906326294}]
# [{'label': 'joy', 'score': 0.9990453124046326}]
# [{'label': 'neutral', 'score': 0.981484055519104}]
# [{'label': 'fear', 'score': 0.9980528354644775}]
# [{'label': 'fear', 'score': 0.9956789612770081}]
# [{'label': 'neutral', 'score': 0.9997552037239075}]
# [{'label': 'neutral', 'score': 0.999349057674408}]
# [{'label': 'surprise', 'score': 0.8489890098571777}]
# [{'label': 'neutral', 'score': 0.975021243095398}]
# [{'label': 'neutral', 'score': 0.9997485280036926}]
# [{'label': 'sadness', 'score': 0.4897722899913788}]
# [{'label': 'neutral', 'score': 0.9995003938674927}]
# [{'label': 'sadness', 'score': 0.999164342880249}]
# [{'label': 'neutral', 'score': 0.9997392296791077}]
# [{'label': 'neutral', 'score': 0.9983271956443787}]
# [{'label': 'neutral', 'score': 0.9595274329185486}]
# [{'label': 'joy', 'score': 0.9991334080696106}]
# [{'label': 'joy', 'score': 0.5748513340950012}]
# [{'label': 'joy', 'score': 0.9495614171028137}]
# [{'label': 'neutral', 'score': 0.9992333650588989}]
# [{'label': 'neutral', 'score': 0.997885525226593}]
# [{'label': 'neutral', 'score': 0.997885525226593}]
# [{'label': 'neutral', 'score': 0.9993398785591125}]
# [{'label': 'neutral', 'score': 0.9978815913200378}]
# [{'label': 'neutral', 'score': 0.9633541107177734}]
# [{'label': 'neutral', 'score': 0.9988239407539368}]
# [{'label': 'fear', 'score': 0.9770854711532593}]
# [{'label': 'neutral', 'score': 0.9997274279594421}]
# [{'label': 'neutral', 'score': 0.9997745156288147}]
# [{'label': 'neutral', 'score': 0.9978815913200378}]
# [{'label': 'neutral', 'score': 0.999725878238678}]
# [{'label': 'anger', 'score': 0.9680259823799133}]
# [{'label': 'sadness', 'score': 0.9985565543174744}]
# [{'label': 'fear', 'score': 0.6579780578613281}]
# [{'label': 'neutral', 'score': 0.9996907711029053}]
# [{'label': 'neutral', 'score': 0.9971466660499573}]
# [{'label': 'neutral', 'score': 0.9997346997261047}]
# [{'label': 'sadness', 'score': 0.9956010580062866}]
# [{'label': 'neutral', 'score': 0.9990910291671753}]
# [{'label': 'neutral', 'score': 0.999599277973175}]
# [{'label': 'neutral', 'score': 0.9608845710754395}]
# [{'label': 'neutral', 'score': 0.9961163997650146}]
# [{'label': 'neutral', 'score': 0.999776303768158}]
# [{'label': 'joy', 'score': 0.9976261258125305}]
# [{'label': 'neutral', 'score': 0.9924788475036621}]
# [{'label': 'sadness', 'score': 0.9892210364341736}]
# [{'label': 'neutral', 'score': 0.9996657371520996}]
# [{'label': 'joy', 'score': 0.9962616562843323}]
# [{'label': 'neutral', 'score': 0.7634013295173645}]
# [{'label': 'joy', 'score': 0.9982293248176575}]
# [{'label': 'neutral', 'score': 0.9975704550743103}]
# [{'label': 'neutral', 'score': 0.9997361302375793}]
# [{'label': 'neutral', 'score': 0.9870637655258179}]
# [{'label': 'neutral', 'score': 0.9988285899162292}]
# [{'label': 'joy', 'score': 0.9989277720451355}]
# [{'label': 'neutral', 'score': 0.9084674715995789}]
# [{'label': 'neutral', 'score': 0.6356751322746277}]
# [{'label': 'neutral', 'score': 0.8876139521598816}]
# [{'label': 'anger', 'score': 0.9841241240501404}]
# [{'label': 'anger', 'score': 0.6353186964988708}]
# [{'label': 'joy', 'score': 0.9981300234794617}]
# [{'label': 'sadness', 'score': 0.9944251775741577}]
# [{'label': 'neutral', 'score': 0.9809631109237671}]
# [{'label': 'joy', 'score': 0.6860692501068115}]
# [{'label': 'surprise', 'score': 0.5855684876441956}]
# [{'label': 'neutral', 'score': 0.9975347518920898}]
# [{'label': 'neutral', 'score': 0.9996767044067383}]
# [{'label': 'neutral', 'score': 0.9988958835601807}]
# [{'label': 'fear', 'score': 0.9243143796920776}]
# [{'label': 'sadness', 'score': 0.9989861845970154}]
# [{'label': 'sadness', 'score': 0.9088813066482544}]
# [{'label': 'sadness', 'score': 0.5438674092292786}]
# [{'label': 'sadness', 'score': 0.5438674092292786}]
# [{'label': 'sadness', 'score': 0.5438674092292786}]
# [{'label': 'neutral', 'score': 0.9996989965438843}]
# [{'label': 'neutral', 'score': 0.8588003516197205}]
# [{'label': 'fear', 'score': 0.5790977478027344}]
# [{'label': 'sadness', 'score': 0.8818332552909851}]
# [{'label': 'joy', 'score': 0.9886581301689148}]
# [{'label': 'neutral', 'score': 0.9874271154403687}]
# [{'label': 'neutral', 'score': 0.5164784789085388}]
# [{'label': 'neutral', 'score': 0.9316183924674988}]
# [{'label': 'sadness', 'score': 0.9386096596717834}]
# [{'label': 'neutral', 'score': 0.9992614388465881}]
# [{'label': 'joy', 'score': 0.9989932179450989}]
# [{'label': 'anger', 'score': 0.8600701093673706}]
# [{'label': 'sadness', 'score': 0.9148780107498169}]
# [{'label': 'fear', 'score': 0.9807586073875427}]
# [{'label': 'sadness', 'score': 0.9975996613502502}]
# [{'label': 'neutral', 'score': 0.9988512992858887}]
# [{'label': 'sadness', 'score': 0.9989433884620667}]
# [{'label': 'sadness', 'score': 0.998336136341095}]
# [{'label': 'neutral', 'score': 0.9994460940361023}]
# [{'label': 'neutral', 'score': 0.7176893949508667}]
# [{'label': 'sadness', 'score': 0.8023486137390137}]
# [{'label': 'fear', 'score': 0.9959828853607178}]
# [{'label': 'fear', 'score': 0.9990600943565369}]
# [{'label': 'fear', 'score': 0.9605873823165894}]
# [{'label': 'sadness', 'score': 0.8023486137390137}]
# [{'label': 'neutral', 'score': 0.9993454813957214}]
# [{'label': 'neutral', 'score': 0.9925416707992554}]
# [{'label': 'fear', 'score': 0.9516379833221436}]
# [{'label': 'neutral', 'score': 0.9355937242507935}]
# [{'label': 'neutral', 'score': 0.9937269687652588}]
# [{'label': 'anger', 'score': 0.948407769203186}]
# [{'label': 'neutral', 'score': 0.994305431842804}]
# [{'label': 'joy', 'score': 0.9679029583930969}]
# [{'label': 'neutral', 'score': 0.9665569067001343}]
# [{'label': 'joy', 'score': 0.7442414164543152}]
# [{'label': 'sadness', 'score': 0.7553493976593018}]

# %%
inference02 = sentiment_classification("tae898/emoberta-large")
# Out:
# [{'label': 'neutral', 'score': 0.49061161279678345}]
# [{'label': 'neutral', 'score': 0.935129702091217}]
# [{'label': 'neutral', 'score': 0.9329481720924377}]
# [{'label': 'neutral', 'score': 0.8697671294212341}]
# [{'label': 'joy', 'score': 0.7094044089317322}]
# [{'label': 'joy', 'score': 0.6961237192153931}]
# [{'label': 'joy', 'score': 0.7699287533760071}]
# [{'label': 'joy', 'score': 0.9007085561752319}]
# [{'label': 'sadness', 'score': 0.7103415727615356}]
# [{'label': 'joy', 'score': 0.7094044089317322}]
# [{'label': 'joy', 'score': 0.7094044089317322}]
# [{'label': 'neutral', 'score': 0.96848464012146}]
# [{'label': 'surprise', 'score': 0.45761367678642273}]
# [{'label': 'neutral', 'score': 0.7680047154426575}]
# [{'label': 'joy', 'score': 0.46369296312332153}]
# [{'label': 'joy', 'score': 0.3338625729084015}]
# [{'label': 'neutral', 'score': 0.5473726391792297}]
# [{'label': 'joy', 'score': 0.390373557806015}]
# [{'label': 'joy', 'score': 0.9153652787208557}]
# [{'label': 'joy', 'score': 0.9153652787208557}]
# [{'label': 'neutral', 'score': 0.96848464012146}]
# [{'label': 'neutral', 'score': 0.9690945148468018}]
# [{'label': 'neutral', 'score': 0.9351913928985596}]
# [{'label': 'anger', 'score': 0.7575079798698425}]
# [{'label': 'neutral', 'score': 0.9781534671783447}]
# [{'label': 'sadness', 'score': 0.5128595232963562}]
# [{'label': 'neutral', 'score': 0.7403550744056702}]
# [{'label': 'disgust', 'score': 0.5791944861412048}]
# [{'label': 'neutral', 'score': 0.5185863971710205}]
# [{'label': 'surprise', 'score': 0.9584785103797913}]
# [{'label': 'neutral', 'score': 0.8259939551353455}]
# [{'label': 'surprise', 'score': 0.5506461262702942}]
# [{'label': 'surprise', 'score': 0.9679639339447021}]
# [{'label': 'joy', 'score': 0.3263476490974426}]
# [{'label': 'surprise', 'score': 0.3271242082118988}]
# [{'label': 'sadness', 'score': 0.2978730797767639}]
# [{'label': 'anger', 'score': 0.5142313838005066}]
# [{'label': 'neutral', 'score': 0.746674656867981}]
# [{'label': 'joy', 'score': 0.6351295113563538}]
# [{'label': 'neutral', 'score': 0.9516144394874573}]
# [{'label': 'neutral', 'score': 0.9516144394874573}]
# [{'label': 'neutral', 'score': 0.4475827217102051}]
# [{'label': 'sadness', 'score': 0.3826010227203369}]
# [{'label': 'neutral', 'score': 0.9179959893226624}]
# [{'label': 'neutral', 'score': 0.9344074130058289}]
# [{'label': 'neutral', 'score': 0.8493456244468689}]
# [{'label': 'neutral', 'score': 0.9710714817047119}]
# [{'label': 'neutral', 'score': 0.9654819369316101}]
# [{'label': 'neutral', 'score': 0.8054786920547485}]
# [{'label': 'surprise', 'score': 0.9376223683357239}]
# [{'label': 'neutral', 'score': 0.9030005931854248}]
# [{'label': 'neutral', 'score': 0.8988493084907532}]
# [{'label': 'sadness', 'score': 0.7439314126968384}]
# [{'label': 'neutral', 'score': 0.9040734171867371}]
# [{'label': 'anger', 'score': 0.4718061685562134}]
# [{'label': 'neutral', 'score': 0.6009991765022278}]
# [{'label': 'neutral', 'score': 0.40079960227012634}]
# [{'label': 'joy', 'score': 0.63929283618927}]
# [{'label': 'surprise', 'score': 0.7169296145439148}]
# [{'label': 'sadness', 'score': 0.7644359469413757}]
# [{'label': 'joy', 'score': 0.9372111558914185}]
# [{'label': 'neutral', 'score': 0.6609530448913574}]
# [{'label': 'neutral', 'score': 0.9659279584884644}]
# [{'label': 'neutral', 'score': 0.49960264563560486}]
# [{'label': 'neutral', 'score': 0.8992785811424255}]
# [{'label': 'neutral', 'score': 0.44767770171165466}]
# [{'label': 'joy', 'score': 0.8477128148078918}]
# [{'label': 'neutral', 'score': 0.9444068670272827}]
# [{'label': 'neutral', 'score': 0.9738286733627319}]
# [{'label': 'surprise', 'score': 0.9294010996818542}]
# [{'label': 'surprise', 'score': 0.96187424659729}]
# [{'label': 'neutral', 'score': 0.9872438311576843}]
# [{'label': 'neutral', 'score': 0.5678455829620361}]
# [{'label': 'surprise', 'score': 0.8207181096076965}]
# [{'label': 'surprise', 'score': 0.3447979986667633}]
# [{'label': 'disgust', 'score': 0.4339655637741089}]
# [{'label': 'neutral', 'score': 0.9670040011405945}]
# [{'label': 'sadness', 'score': 0.37170925736427307}]
# [{'label': 'neutral', 'score': 0.8595225811004639}]
# [{'label': 'joy', 'score': 0.37831446528434753}]
# [{'label': 'sadness', 'score': 0.5296240448951721}]
# [{'label': 'surprise', 'score': 0.6615522503852844}]
# [{'label': 'neutral', 'score': 0.9098318815231323}]
# [{'label': 'neutral', 'score': 0.9592771530151367}]
# [{'label': 'neutral', 'score': 0.39988017082214355}]
# [{'label': 'neutral', 'score': 0.9501938819885254}]
# [{'label': 'sadness', 'score': 0.9534887671470642}]
# [{'label': 'neutral', 'score': 0.9524927139282227}]
# [{'label': 'fear', 'score': 0.4227098822593689}]
# [{'label': 'sadness', 'score': 0.766060471534729}]
# [{'label': 'neutral', 'score': 0.3573746979236603}]
# [{'label': 'neutral', 'score': 0.7644674181938171}]
# [{'label': 'neutral', 'score': 0.96848464012146}]
# [{'label': 'surprise', 'score': 0.6401340365409851}]
# [{'label': 'neutral', 'score': 0.9828552007675171}]
# [{'label': 'sadness', 'score': 0.5320844650268555}]
# [{'label': 'anger', 'score': 0.9032291769981384}]
# [{'label': 'anger', 'score': 0.9093848466873169}]
# [{'label': 'joy', 'score': 0.4955694377422333}]
# [{'label': 'neutral', 'score': 0.8074090480804443}]
# [{'label': 'neutral', 'score': 0.9715608358383179}]
# [{'label': 'joy', 'score': 0.8306313753128052}]
# [{'label': 'neutral', 'score': 0.5275036096572876}]
# [{'label': 'neutral', 'score': 0.6616887450218201}]
# [{'label': 'neutral', 'score': 0.48597055673599243}]
# [{'label': 'joy', 'score': 0.953927755355835}]
# [{'label': 'surprise', 'score': 0.4522804319858551}]
# [{'label': 'neutral', 'score': 0.5637399554252625}]
# [{'label': 'neutral', 'score': 0.8128639459609985}]
# [{'label': 'neutral', 'score': 0.9209097027778625}]
# [{'label': 'neutral', 'score': 0.9780513048171997}]
# [{'label': 'neutral', 'score': 0.7711990475654602}]
# [{'label': 'anger', 'score': 0.7864724397659302}]
# [{'label': 'neutral', 'score': 0.8988493084907532}]
# [{'label': 'neutral', 'score': 0.8959020972251892}]
# [{'label': 'neutral', 'score': 0.8513330817222595}]
# [{'label': 'joy', 'score': 0.4474312365055084}]
# [{'label': 'neutral', 'score': 0.8180012106895447}]
# [{'label': 'anger', 'score': 0.8811560273170471}]
# [{'label': 'anger', 'score': 0.9187991619110107}]
# [{'label': 'sadness', 'score': 0.32033002376556396}]
# [{'label': 'surprise', 'score': 0.9326721429824829}]
# [{'label': 'joy', 'score': 0.8852024078369141}]
# [{'label': 'joy', 'score': 0.8852024078369141}]
# [{'label': 'joy', 'score': 0.8852024078369141}]
# [{'label': 'neutral', 'score': 0.9303622245788574}]
# [{'label': 'neutral', 'score': 0.5139820575714111}]
# [{'label': 'joy', 'score': 0.6024432182312012}]
# [{'label': 'joy', 'score': 0.8242735266685486}]
# [{'label': 'neutral', 'score': 0.9718948602676392}]
# [{'label': 'joy', 'score': 0.8717280626296997}]
# [{'label': 'joy', 'score': 0.784995436668396}]
# [{'label': 'joy', 'score': 0.8490484356880188}]
# [{'label': 'disgust', 'score': 0.5085579752922058}]
# [{'label': 'joy', 'score': 0.5063840746879578}]
# [{'label': 'neutral', 'score': 0.7474353313446045}]
# [{'label': 'neutral', 'score': 0.7474353313446045}]
# [{'label': 'anger', 'score': 0.9663130640983582}]
# [{'label': 'neutral', 'score': 0.990116536617279}]
# [{'label': 'neutral', 'score': 0.9229442477226257}]
# [{'label': 'neutral', 'score': 0.8712512850761414}]
# [{'label': 'neutral', 'score': 0.9349663853645325}]
# [{'label': 'joy', 'score': 0.4522304832935333}]
# [{'label': 'neutral', 'score': 0.9134025573730469}]
# [{'label': 'neutral', 'score': 0.9361037015914917}]
# [{'label': 'joy', 'score': 0.7762057781219482}]
# [{'label': 'neutral', 'score': 0.894325315952301}]
# [{'label': 'joy', 'score': 0.7708274126052856}]
# [{'label': 'neutral', 'score': 0.8708805441856384}]
# [{'label': 'neutral', 'score': 0.8838837146759033}]
# [{'label': 'neutral', 'score': 0.5766343474388123}]
# [{'label': 'disgust', 'score': 0.8424497246742249}]
# [{'label': 'anger', 'score': 0.8851324319839478}]
# [{'label': 'joy', 'score': 0.9256365299224854}]
# [{'label': 'surprise', 'score': 0.6397358775138855}]
# [{'label': 'anger', 'score': 0.5767816305160522}]
# [{'label': 'joy', 'score': 0.6117776036262512}]
# [{'label': 'anger', 'score': 0.39828845858573914}]
# [{'label': 'sadness', 'score': 0.7323691844940186}]
# [{'label': 'sadness', 'score': 0.8762187361717224}]
# [{'label': 'disgust', 'score': 0.8248223066329956}]
# [{'label': 'neutral', 'score': 0.9415370225906372}]
# [{'label': 'anger', 'score': 0.6836745142936707}]
# [{'label': 'neutral', 'score': 0.9867033958435059}]
# [{'label': 'fear', 'score': 0.7275387644767761}]
# [{'label': 'anger', 'score': 0.39591139554977417}]
# [{'label': 'neutral', 'score': 0.9501082897186279}]
# [{'label': 'neutral', 'score': 0.9608545303344727}]
# [{'label': 'neutral', 'score': 0.652768075466156}]
# [{'label': 'neutral', 'score': 0.9692800641059875}]
# [{'label': 'neutral', 'score': 0.9191967844963074}]
# [{'label': 'neutral', 'score': 0.9622395634651184}]
# [{'label': 'sadness', 'score': 0.8349664211273193}]
# [{'label': 'neutral', 'score': 0.8961225152015686}]
# [{'label': 'anger', 'score': 0.8746534585952759}]
# [{'label': 'anger', 'score': 0.7566466331481934}]
# [{'label': 'sadness', 'score': 0.7859212160110474}]
# [{'label': 'anger', 'score': 0.9544955492019653}]
# [{'label': 'anger', 'score': 0.8160116076469421}]
# [{'label': 'anger', 'score': 0.9560097455978394}]
# [{'label': 'neutral', 'score': 0.9797805547714233}]
# [{'label': 'neutral', 'score': 0.8906493782997131}]
# [{'label': 'neutral', 'score': 0.5912116169929504}]
# [{'label': 'neutral', 'score': 0.6595050692558289}]
# [{'label': 'joy', 'score': 0.4718805253505707}]
# [{'label': 'anger', 'score': 0.886635959148407}]
# [{'label': 'neutral', 'score': 0.9782618284225464}]
# [{'label': 'neutral', 'score': 0.8266955614089966}]
# [{'label': 'neutral', 'score': 0.9162217974662781}]
# [{'label': 'neutral', 'score': 0.49331051111221313}]
# [{'label': 'neutral', 'score': 0.8042130470275879}]
# [{'label': 'neutral', 'score': 0.432981014251709}]
# [{'label': 'neutral', 'score': 0.5813808441162109}]
# [{'label': 'neutral', 'score': 0.9387304782867432}]
# [{'label': 'neutral', 'score': 0.9551699161529541}]
# [{'label': 'neutral', 'score': 0.9515606164932251}]
# [{'label': 'neutral', 'score': 0.8176647424697876}]
# [{'label': 'sadness', 'score': 0.9087454080581665}]
# [{'label': 'joy', 'score': 0.7629359364509583}]
# [{'label': 'surprise', 'score': 0.9007283449172974}]
# [{'label': 'joy', 'score': 0.6024432182312012}]
# [{'label': 'neutral', 'score': 0.9516144394874573}]
# [{'label': 'sadness', 'score': 0.7668341398239136}]
# [{'label': 'neutral', 'score': 0.5523371696472168}]
# [{'label': 'sadness', 'score': 0.9323297739028931}]
# [{'label': 'neutral', 'score': 0.8259939551353455}]
# [{'label': 'sadness', 'score': 0.7289572954177856}]
# [{'label': 'neutral', 'score': 0.6075522899627686}]
# [{'label': 'sadness', 'score': 0.8399096727371216}]
# [{'label': 'anger', 'score': 0.47607311606407166}]
# [{'label': 'anger', 'score': 0.4574974775314331}]
# [{'label': 'joy', 'score': 0.2783377766609192}]
# [{'label': 'joy', 'score': 0.9633411169052124}]
# [{'label': 'neutral', 'score': 0.8165513277053833}]
# [{'label': 'neutral', 'score': 0.5916939377784729}]
# [{'label': 'neutral', 'score': 0.6505186557769775}]
# [{'label': 'neutral', 'score': 0.8750035166740417}]
# [{'label': 'joy', 'score': 0.8821801543235779}]
# [{'label': 'joy', 'score': 0.7430973052978516}]
# [{'label': 'neutral', 'score': 0.6188503503799438}]
# [{'label': 'sadness', 'score': 0.718084990978241}]
# [{'label': 'neutral', 'score': 0.96848464012146}]
# [{'label': 'joy', 'score': 0.6181787848472595}]
# [{'label': 'neutral', 'score': 0.9463803172111511}]
# [{'label': 'neutral', 'score': 0.4203765094280243}]
# [{'label': 'neutral', 'score': 0.856357216835022}]
# [{'label': 'joy', 'score': 0.8852024078369141}]
# [{'label': 'neutral', 'score': 0.9200604557991028}]
# [{'label': 'joy', 'score': 0.7993249297142029}]
# [{'label': 'surprise', 'score': 0.4194314181804657}]
# [{'label': 'anger', 'score': 0.5700554847717285}]
# [{'label': 'sadness', 'score': 0.7754120230674744}]
# [{'label': 'neutral', 'score': 0.897671103477478}]
# [{'label': 'surprise', 'score': 0.6098536849021912}]
# [{'label': 'surprise', 'score': 0.9679639339447021}]
# [{'label': 'joy', 'score': 0.9052240252494812}]
# [{'label': 'neutral', 'score': 0.9804038405418396}]
# [{'label': 'anger', 'score': 0.9545536637306213}]
# [{'label': 'neutral', 'score': 0.7285848259925842}]
# [{'label': 'anger', 'score': 0.6986311674118042}]
# [{'label': 'neutral', 'score': 0.5302901864051819}]
# [{'label': 'joy', 'score': 0.971758246421814}]
# [{'label': 'neutral', 'score': 0.5569947361946106}]
# [{'label': 'sadness', 'score': 0.4252742528915405}]
# [{'label': 'joy', 'score': 0.4817669987678528}]
# [{'label': 'neutral', 'score': 0.34040558338165283}]
# [{'label': 'joy', 'score': 0.7240148782730103}]
# [{'label': 'joy', 'score': 0.6181787848472595}]
# [{'label': 'neutral', 'score': 0.9516144394874573}]
# [{'label': 'neutral', 'score': 0.9639514088630676}]
# [{'label': 'sadness', 'score': 0.692686915397644}]
# [{'label': 'neutral', 'score': 0.9551238417625427}]
# [{'label': 'sadness', 'score': 0.8618825674057007}]
# [{'label': 'neutral', 'score': 0.8865258097648621}]
# [{'label': 'neutral', 'score': 0.8726580739021301}]
# [{'label': 'neutral', 'score': 0.6990768909454346}]
# [{'label': 'neutral', 'score': 0.6331658959388733}]
# [{'label': 'neutral', 'score': 0.9658946990966797}]
# [{'label': 'sadness', 'score': 0.7478821277618408}]
# [{'label': 'surprise', 'score': 0.2706959843635559}]
# [{'label': 'neutral', 'score': 0.6988129615783691}]
# [{'label': 'neutral', 'score': 0.9262215495109558}]
# [{'label': 'neutral', 'score': 0.9758460521697998}]
# [{'label': 'joy', 'score': 0.9332666993141174}]
# [{'label': 'surprise', 'score': 0.9294840097427368}]
# [{'label': 'neutral', 'score': 0.9824603199958801}]
# [{'label': 'neutral', 'score': 0.867167592048645}]
# [{'label': 'neutral', 'score': 0.3419756591320038}]
# [{'label': 'neutral', 'score': 0.9726154804229736}]
# [{'label': 'surprise', 'score': 0.9318493008613586}]
# [{'label': 'neutral', 'score': 0.8259939551353455}]
# [{'label': 'neutral', 'score': 0.5771307945251465}]
# [{'label': 'anger', 'score': 0.42382070422172546}]
# [{'label': 'joy', 'score': 0.915191650390625}]
# [{'label': 'neutral', 'score': 0.9707066416740417}]
# [{'label': 'neutral', 'score': 0.6442531943321228}]
# [{'label': 'joy', 'score': 0.5915676355361938}]
# [{'label': 'neutral', 'score': 0.6026424765586853}]
# [{'label': 'joy', 'score': 0.9155184626579285}]
# [{'label': 'surprise', 'score': 0.9604235291481018}]
# [{'label': 'surprise', 'score': 0.5276208519935608}]
# [{'label': 'joy', 'score': 0.6705248355865479}]
# [{'label': 'sadness', 'score': 0.9549410343170166}]
# [{'label': 'neutral', 'score': 0.8852576017379761}]
# [{'label': 'joy', 'score': 0.9149501323699951}]
# [{'label': 'neutral', 'score': 0.9507638812065125}]
# [{'label': 'fear', 'score': 0.3242664039134979}]
# [{'label': 'joy', 'score': 0.5329558849334717}]
# [{'label': 'neutral', 'score': 0.9509323835372925}]
# [{'label': 'neutral', 'score': 0.8988493084907532}]
# [{'label': 'neutral', 'score': 0.9446718096733093}]
# [{'label': 'sadness', 'score': 0.8475107550621033}]
# [{'label': 'neutral', 'score': 0.9325319528579712}]
# [{'label': 'neutral', 'score': 0.6025303602218628}]
# [{'label': 'surprise', 'score': 0.9051952362060547}]
# [{'label': 'sadness', 'score': 0.797061562538147}]
# [{'label': 'sadness', 'score': 0.8368415236473083}]
# [{'label': 'sadness', 'score': 0.9640274047851562}]
# [{'label': 'joy', 'score': 0.9229581356048584}]
# [{'label': 'anger', 'score': 0.907368004322052}]
# [{'label': 'anger', 'score': 0.976974606513977}]
# [{'label': 'neutral', 'score': 0.8835276961326599}]
# [{'label': 'neutral', 'score': 0.96848464012146}]
# [{'label': 'joy', 'score': 0.5952345132827759}]
# [{'label': 'fear', 'score': 0.4110026955604553}]
# [{'label': 'sadness', 'score': 0.7293156385421753}]
# [{'label': 'neutral', 'score': 0.7017592787742615}]
# [{'label': 'neutral', 'score': 0.6593250036239624}]
# [{'label': 'anger', 'score': 0.3431888222694397}]
# [{'label': 'neutral', 'score': 0.8170167803764343}]
# [{'label': 'anger', 'score': 0.8591548204421997}]
# [{'label': 'anger', 'score': 0.612678050994873}]
# [{'label': 'joy', 'score': 0.7415714859962463}]
# [{'label': 'neutral', 'score': 0.5508633255958557}]
# [{'label': 'joy', 'score': 0.3951960802078247}]
# [{'label': 'surprise', 'score': 0.9710521697998047}]
# [{'label': 'joy', 'score': 0.5802898406982422}]
# [{'label': 'anger', 'score': 0.874891996383667}]
# [{'label': 'neutral', 'score': 0.4987029731273651}]
# [{'label': 'neutral', 'score': 0.9820605516433716}]
# [{'label': 'neutral', 'score': 0.9483019709587097}]
# [{'label': 'neutral', 'score': 0.7847057580947876}]
# [{'label': 'joy', 'score': 0.8142415285110474}]
# [{'label': 'joy', 'score': 0.573811948299408}]
# [{'label': 'anger', 'score': 0.6060656309127808}]
# [{'label': 'anger', 'score': 0.6035710573196411}]
# [{'label': 'neutral', 'score': 0.7209844589233398}]
# [{'label': 'anger', 'score': 0.8479302525520325}]
# [{'label': 'surprise', 'score': 0.4230501353740692}]
# [{'label': 'joy', 'score': 0.7088181376457214}]
# [{'label': 'joy', 'score': 0.7918527126312256}]
# [{'label': 'neutral', 'score': 0.9775394201278687}]
# [{'label': 'neutral', 'score': 0.8885500431060791}]
# [{'label': 'neutral', 'score': 0.9780006408691406}]
# [{'label': 'neutral', 'score': 0.9415649175643921}]
# [{'label': 'anger', 'score': 0.4479760527610779}]
# [{'label': 'anger', 'score': 0.4717847406864166}]
# [{'label': 'neutral', 'score': 0.6157098412513733}]
# [{'label': 'anger', 'score': 0.596237301826477}]
# [{'label': 'surprise', 'score': 0.49833792448043823}]
# [{'label': 'neutral', 'score': 0.7951520681381226}]
# [{'label': 'neutral', 'score': 0.770939290523529}]
# [{'label': 'fear', 'score': 0.6348873376846313}]
# [{'label': 'joy', 'score': 0.6926644444465637}]
# [{'label': 'joy', 'score': 0.7597392797470093}]
# [{'label': 'joy', 'score': 0.9801969528198242}]
# [{'label': 'neutral', 'score': 0.6274034976959229}]
# [{'label': 'joy', 'score': 0.9063502550125122}]
# [{'label': 'joy', 'score': 0.9862352013587952}]
# [{'label': 'neutral', 'score': 0.866042971611023}]
# [{'label': 'neutral', 'score': 0.8874076008796692}]
# [{'label': 'neutral', 'score': 0.816626250743866}]
# [{'label': 'anger', 'score': 0.5442728996276855}]
# [{'label': 'neutral', 'score': 0.75676429271698}]
# [{'label': 'neutral', 'score': 0.6702852249145508}]
# [{'label': 'joy', 'score': 0.7389456033706665}]
# [{'label': 'neutral', 'score': 0.5591152310371399}]
# [{'label': 'sadness', 'score': 0.7904757261276245}]
# [{'label': 'surprise', 'score': 0.9581647515296936}]
# [{'label': 'joy', 'score': 0.68056321144104}]
# [{'label': 'neutral', 'score': 0.6921282410621643}]
# [{'label': 'joy', 'score': 0.9600641131401062}]
# [{'label': 'sadness', 'score': 0.7700883150100708}]
# [{'label': 'joy', 'score': 0.8371254205703735}]
# [{'label': 'joy', 'score': 0.9578425884246826}]
# [{'label': 'surprise', 'score': 0.39657318592071533}]
# [{'label': 'surprise', 'score': 0.4755108654499054}]
# [{'label': 'neutral', 'score': 0.9625945091247559}]
# [{'label': 'surprise', 'score': 0.9447085857391357}]
# [{'label': 'neutral', 'score': 0.587742030620575}]
# [{'label': 'neutral', 'score': 0.9731329083442688}]
# [{'label': 'surprise', 'score': 0.3232323229312897}]
# [{'label': 'joy', 'score': 0.41126033663749695}]
# [{'label': 'sadness', 'score': 0.5261647701263428}]
# [{'label': 'sadness', 'score': 0.9173568487167358}]
# [{'label': 'neutral', 'score': 0.6264302134513855}]
# [{'label': 'neutral', 'score': 0.5976421236991882}]
# [{'label': 'sadness', 'score': 0.7373130321502686}]
# [{'label': 'neutral', 'score': 0.9690961837768555}]
# [{'label': 'joy', 'score': 0.5260363817214966}]
# [{'label': 'neutral', 'score': 0.7536556124687195}]
# [{'label': 'neutral', 'score': 0.8259939551353455}]
# [{'label': 'neutral', 'score': 0.9059222340583801}]
# [{'label': 'neutral', 'score': 0.7622707486152649}]
# [{'label': 'neutral', 'score': 0.9207602143287659}]
# [{'label': 'neutral', 'score': 0.925280749797821}]
# [{'label': 'neutral', 'score': 0.9612008333206177}]
# [{'label': 'neutral', 'score': 0.9594220519065857}]
# [{'label': 'anger', 'score': 0.5560426712036133}]
# [{'label': 'joy', 'score': 0.8798837065696716}]
# [{'label': 'anger', 'score': 0.9418091177940369}]
# [{'label': 'neutral', 'score': 0.8988493084907532}]
# [{'label': 'neutral', 'score': 0.7222020030021667}]
# [{'label': 'neutral', 'score': 0.6356031894683838}]
# [{'label': 'surprise', 'score': 0.3291417062282562}]
# [{'label': 'neutral', 'score': 0.9541923999786377}]
# [{'label': 'surprise', 'score': 0.7129312753677368}]
# [{'label': 'joy', 'score': 0.9631072282791138}]
# [{'label': 'neutral', 'score': 0.9536711573600769}]
# [{'label': 'surprise', 'score': 0.972515881061554}]
# [{'label': 'joy', 'score': 0.9582321643829346}]
# [{'label': 'joy', 'score': 0.956364631652832}]
# [{'label': 'anger', 'score': 0.8856960535049438}]
# [{'label': 'anger', 'score': 0.9735137224197388}]
# [{'label': 'joy', 'score': 0.5867759585380554}]
# [{'label': 'joy', 'score': 0.9387893080711365}]
# [{'label': 'neutral', 'score': 0.7198213934898376}]
# [{'label': 'joy', 'score': 0.5412684082984924}]
# [{'label': 'neutral', 'score': 0.755774736404419}]
# [{'label': 'joy', 'score': 0.6060049533843994}]
# [{'label': 'joy', 'score': 0.9411433339118958}]
# [{'label': 'neutral', 'score': 0.9703251123428345}]
# [{'label': 'disgust', 'score': 0.6480239629745483}]
# [{'label': 'joy', 'score': 0.9341112971305847}]
# [{'label': 'sadness', 'score': 0.9707712531089783}]
# [{'label': 'neutral', 'score': 0.9851717948913574}]
# [{'label': 'neutral', 'score': 0.988884449005127}]
# [{'label': 'neutral', 'score': 0.9830431342124939}]
# [{'label': 'neutral', 'score': 0.655859649181366}]
# [{'label': 'neutral', 'score': 0.5733070969581604}]
# [{'label': 'neutral', 'score': 0.8450551629066467}]
# [{'label': 'neutral', 'score': 0.5233887434005737}]
# [{'label': 'neutral', 'score': 0.9516144394874573}]
# [{'label': 'joy', 'score': 0.6024432182312012}]
# [{'label': 'neutral', 'score': 0.9516144394874573}]
# [{'label': 'neutral', 'score': 0.97555011510849}]
# [{'label': 'neutral', 'score': 0.8444294929504395}]
# [{'label': 'joy', 'score': 0.7976427674293518}]
# [{'label': 'neutral', 'score': 0.9828243255615234}]
# [{'label': 'fear', 'score': 0.4951300323009491}]
# [{'label': 'neutral', 'score': 0.5259403586387634}]
# [{'label': 'joy', 'score': 0.952152669429779}]
# [{'label': 'joy', 'score': 0.9670734405517578}]
# [{'label': 'joy', 'score': 0.9650720357894897}]
# [{'label': 'joy', 'score': 0.953728437423706}]
# [{'label': 'joy', 'score': 0.6181787848472595}]
# [{'label': 'joy', 'score': 0.6181787848472595}]
# [{'label': 'neutral', 'score': 0.8052182197570801}]
# [{'label': 'neutral', 'score': 0.9803992509841919}]
# [{'label': 'neutral', 'score': 0.954834520816803}]
# [{'label': 'anger', 'score': 0.5363993644714355}]
# [{'label': 'neutral', 'score': 0.8186899423599243}]
# [{'label': 'neutral', 'score': 0.9692800641059875}]
# [{'label': 'sadness', 'score': 0.49157077074050903}]
# [{'label': 'joy', 'score': 0.6024432182312012}]
# [{'label': 'sadness', 'score': 0.44178473949432373}]
# [{'label': 'joy', 'score': 0.9476904273033142}]
# [{'label': 'surprise', 'score': 0.5201709866523743}]
# [{'label': 'neutral', 'score': 0.8859303593635559}]
# [{'label': 'joy', 'score': 0.9672247767448425}]
# [{'label': 'neutral', 'score': 0.7443904280662537}]
# [{'label': 'surprise', 'score': 0.6657792925834656}]
# [{'label': 'neutral', 'score': 0.987037181854248}]
# [{'label': 'neutral', 'score': 0.8276572227478027}]
# [{'label': 'sadness', 'score': 0.7514110803604126}]
# [{'label': 'neutral', 'score': 0.8937286138534546}]
# [{'label': 'joy', 'score': 0.6024432182312012}]
# [{'label': 'joy', 'score': 0.6181787848472595}]
# [{'label': 'neutral', 'score': 0.49041497707366943}]
# [{'label': 'neutral', 'score': 0.9677982330322266}]
# [{'label': 'anger', 'score': 0.48272252082824707}]
# [{'label': 'neutral', 'score': 0.9562042951583862}]
# [{'label': 'neutral', 'score': 0.501227617263794}]
# [{'label': 'neutral', 'score': 0.8757158517837524}]
# [{'label': 'neutral', 'score': 0.9748138189315796}]
# [{'label': 'neutral', 'score': 0.9500425457954407}]
# [{'label': 'surprise', 'score': 0.7504371404647827}]
# [{'label': 'surprise', 'score': 0.8955041170120239}]
# [{'label': 'neutral', 'score': 0.6050593256950378}]
# [{'label': 'joy', 'score': 0.8095532059669495}]
# [{'label': 'surprise', 'score': 0.5772219896316528}]
# [{'label': 'surprise', 'score': 0.5688017010688782}]
# [{'label': 'neutral', 'score': 0.6495799422264099}]
# [{'label': 'joy', 'score': 0.9545761346817017}]
# [{'label': 'joy', 'score': 0.9734302163124084}]
# [{'label': 'joy', 'score': 0.9795235991477966}]
# [{'label': 'sadness', 'score': 0.6953185200691223}]
# [{'label': 'neutral', 'score': 0.5323196649551392}]
# [{'label': 'disgust', 'score': 0.3194531202316284}]
# [{'label': 'surprise', 'score': 0.7773746848106384}]
# [{'label': 'neutral', 'score': 0.5345741510391235}]
# [{'label': 'neutral', 'score': 0.9295229315757751}]
# [{'label': 'joy', 'score': 0.9439013600349426}]
# [{'label': 'joy', 'score': 0.9822371602058411}]
# [{'label': 'anger', 'score': 0.7913634181022644}]
# [{'label': 'anger', 'score': 0.7586382031440735}]
# [{'label': 'anger', 'score': 0.5595097541809082}]
# [{'label': 'anger', 'score': 0.8258008360862732}]
# [{'label': 'anger', 'score': 0.5809353590011597}]
# [{'label': 'neutral', 'score': 0.5439165830612183}]
# [{'label': 'neutral', 'score': 0.8836733102798462}]
# [{'label': 'anger', 'score': 0.7026939988136292}]
# [{'label': 'anger', 'score': 0.5839827060699463}]
# [{'label': 'anger', 'score': 0.7030613422393799}]
# [{'label': 'sadness', 'score': 0.5464335680007935}]
# [{'label': 'anger', 'score': 0.4558700919151306}]
# [{'label': 'neutral', 'score': 0.8340872526168823}]
# [{'label': 'neutral', 'score': 0.8775678873062134}]
# [{'label': 'surprise', 'score': 0.5619415044784546}]
# [{'label': 'sadness', 'score': 0.7827866077423096}]
# [{'label': 'neutral', 'score': 0.4769415259361267}]
# [{'label': 'joy', 'score': 0.9764684438705444}]
# [{'label': 'neutral', 'score': 0.6513277292251587}]
# [{'label': 'anger', 'score': 0.7613499164581299}]
# [{'label': 'neutral', 'score': 0.43340250849723816}]
# [{'label': 'neutral', 'score': 0.7433767318725586}]
# [{'label': 'neutral', 'score': 0.6466694474220276}]
# [{'label': 'joy', 'score': 0.7659088969230652}]
# [{'label': 'neutral', 'score': 0.9530802369117737}]
# [{'label': 'surprise', 'score': 0.7679107785224915}]
# [{'label': 'joy', 'score': 0.8650814294815063}]
# [{'label': 'neutral', 'score': 0.935019850730896}]
# [{'label': 'neutral', 'score': 0.6775078773498535}]
# [{'label': 'anger', 'score': 0.6158507466316223}]
# [{'label': 'neutral', 'score': 0.8551911115646362}]
# [{'label': 'joy', 'score': 0.9809837937355042}]
# [{'label': 'joy', 'score': 0.5274388194084167}]
# [{'label': 'joy', 'score': 0.6024432182312012}]
# [{'label': 'joy', 'score': 0.6024432182312012}]
# [{'label': 'joy', 'score': 0.4545954465866089}]
# [{'label': 'disgust', 'score': 0.5203994512557983}]
# [{'label': 'neutral', 'score': 0.969197154045105}]
# [{'label': 'neutral', 'score': 0.9233415722846985}]
# [{'label': 'neutral', 'score': 0.8988493084907532}]
# [{'label': 'joy', 'score': 0.46965348720550537}]
# [{'label': 'joy', 'score': 0.3556957244873047}]
# [{'label': 'sadness', 'score': 0.9165358543395996}]
# [{'label': 'sadness', 'score': 0.7470122575759888}]
# [{'label': 'neutral', 'score': 0.7764415144920349}]
# [{'label': 'joy', 'score': 0.8990766406059265}]
# [{'label': 'joy', 'score': 0.9814203381538391}]
# [{'label': 'neutral', 'score': 0.9358586072921753}]
# [{'label': 'neutral', 'score': 0.9175059199333191}]
# [{'label': 'sadness', 'score': 0.6759982705116272}]
# [{'label': 'neutral', 'score': 0.9594243764877319}]
# [{'label': 'neutral', 'score': 0.7648167610168457}]
# [{'label': 'neutral', 'score': 0.5299690961837769}]
# [{'label': 'fear', 'score': 0.5704774856567383}]
# [{'label': 'neutral', 'score': 0.4832577705383301}]
# [{'label': 'neutral', 'score': 0.8967525362968445}]
# [{'label': 'joy', 'score': 0.6892176866531372}]
# [{'label': 'sadness', 'score': 0.8580412864685059}]
# [{'label': 'anger', 'score': 0.8339488506317139}]
# [{'label': 'surprise', 'score': 0.6728758215904236}]
# [{'label': 'joy', 'score': 0.8672139048576355}]
# [{'label': 'anger', 'score': 0.3990192115306854}]
# [{'label': 'surprise', 'score': 0.6506229639053345}]
# [{'label': 'neutral', 'score': 0.7433767318725586}]
# [{'label': 'neutral', 'score': 0.5753623247146606}]
# [{'label': 'neutral', 'score': 0.9564454555511475}]
# [{'label': 'joy', 'score': 0.6024432182312012}]
# [{'label': 'anger', 'score': 0.8325694799423218}]
# [{'label': 'neutral', 'score': 0.7988190650939941}]
# [{'label': 'anger', 'score': 0.708338737487793}]
# [{'label': 'joy', 'score': 0.43715861439704895}]
# [{'label': 'joy', 'score': 0.8852024078369141}]
# [{'label': 'neutral', 'score': 0.5978255271911621}]
# [{'label': 'neutral', 'score': 0.9489455819129944}]
# [{'label': 'neutral', 'score': 0.9515606164932251}]
# [{'label': 'sadness', 'score': 0.6824681162834167}]
# [{'label': 'neutral', 'score': 0.9658660888671875}]
# [{'label': 'neutral', 'score': 0.8065829873085022}]
# [{'label': 'sadness', 'score': 0.453601211309433}]
# [{'label': 'sadness', 'score': 0.7422246336936951}]
# [{'label': 'neutral', 'score': 0.9691921472549438}]
# [{'label': 'neutral', 'score': 0.5439165830612183}]
# [{'label': 'neutral', 'score': 0.9775300621986389}]
# [{'label': 'neutral', 'score': 0.9179521799087524}]
# [{'label': 'neutral', 'score': 0.9200944900512695}]
# [{'label': 'neutral', 'score': 0.8168669939041138}]
# [{'label': 'neutral', 'score': 0.9850090742111206}]
# [{'label': 'surprise', 'score': 0.73193359375}]
# [{'label': 'neutral', 'score': 0.9250151515007019}]
# [{'label': 'neutral', 'score': 0.9564788341522217}]
# [{'label': 'joy', 'score': 0.3967716693878174}]
# [{'label': 'neutral', 'score': 0.9839681386947632}]
# [{'label': 'neutral', 'score': 0.9812397956848145}]
# [{'label': 'joy', 'score': 0.42869138717651367}]
# [{'label': 'neutral', 'score': 0.693220317363739}]
# [{'label': 'neutral', 'score': 0.8072725534439087}]
# [{'label': 'joy', 'score': 0.6414263844490051}]
# [{'label': 'joy', 'score': 0.9610406756401062}]
# [{'label': 'neutral', 'score': 0.9635624289512634}]
# [{'label': 'joy', 'score': 0.9715321660041809}]
# [{'label': 'neutral', 'score': 0.9125766158103943}]
# [{'label': 'neutral', 'score': 0.9584524631500244}]
# [{'label': 'neutral', 'score': 0.8833706974983215}]
# [{'label': 'joy', 'score': 0.6702309846878052}]
# [{'label': 'anger', 'score': 0.6308035850524902}]
# [{'label': 'anger', 'score': 0.869696319103241}]
# [{'label': 'neutral', 'score': 0.981704592704773}]
# [{'label': 'surprise', 'score': 0.9209108352661133}]
# [{'label': 'neutral', 'score': 0.7061430811882019}]
# [{'label': 'fear', 'score': 0.3747280538082123}]
# [{'label': 'neutral', 'score': 0.5637399554252625}]
# [{'label': 'neutral', 'score': 0.8835777044296265}]
# [{'label': 'neutral', 'score': 0.5637399554252625}]
# [{'label': 'joy', 'score': 0.8396654725074768}]
# [{'label': 'neutral', 'score': 0.5637399554252625}]
# [{'label': 'anger', 'score': 0.7902580499649048}]
# [{'label': 'neutral', 'score': 0.44241318106651306}]
# [{'label': 'neutral', 'score': 0.8259939551353455}]
# [{'label': 'joy', 'score': 0.9269775152206421}]
# [{'label': 'anger', 'score': 0.9711591005325317}]
# [{'label': 'surprise', 'score': 0.6362354159355164}]
# [{'label': 'surprise', 'score': 0.35302478075027466}]
# [{'label': 'sadness', 'score': 0.42044809460639954}]
# [{'label': 'sadness', 'score': 0.5067098140716553}]
# [{'label': 'anger', 'score': 0.8200476169586182}]
# [{'label': 'neutral', 'score': 0.9615986943244934}]
# [{'label': 'neutral', 'score': 0.9727346897125244}]
# [{'label': 'neutral', 'score': 0.8652916550636292}]
# [{'label': 'neutral', 'score': 0.7651519775390625}]
# [{'label': 'neutral', 'score': 0.48575055599212646}]
# [{'label': 'neutral', 'score': 0.9767597317695618}]
# [{'label': 'neutral', 'score': 0.8717811703681946}]
# [{'label': 'joy', 'score': 0.5576826930046082}]
# [{'label': 'sadness', 'score': 0.38034316897392273}]
# [{'label': 'anger', 'score': 0.610578179359436}]
# [{'label': 'disgust', 'score': 0.7500593066215515}]
# [{'label': 'anger', 'score': 0.6277022361755371}]
# [{'label': 'anger', 'score': 0.9283117055892944}]
# [{'label': 'neutral', 'score': 0.5295465588569641}]
# [{'label': 'anger', 'score': 0.8377813100814819}]
# [{'label': 'neutral', 'score': 0.5558596253395081}]
# [{'label': 'sadness', 'score': 0.96110600233078}]
# [{'label': 'joy', 'score': 0.3037475645542145}]
# [{'label': 'neutral', 'score': 0.9722524881362915}]
# [{'label': 'neutral', 'score': 0.9785672426223755}]
# [{'label': 'neutral', 'score': 0.9457907676696777}]
# [{'label': 'neutral', 'score': 0.930503785610199}]
# [{'label': 'joy', 'score': 0.9548972249031067}]
# [{'label': 'joy', 'score': 0.7570921778678894}]
# [{'label': 'neutral', 'score': 0.7433767318725586}]
# [{'label': 'joy', 'score': 0.8573951721191406}]
# [{'label': 'joy', 'score': 0.9701922535896301}]
# [{'label': 'neutral', 'score': 0.9688904285430908}]
# [{'label': 'surprise', 'score': 0.9294010996818542}]
# [{'label': 'surprise', 'score': 0.47239264845848083}]
# [{'label': 'neutral', 'score': 0.9779384136199951}]
# [{'label': 'neutral', 'score': 0.9218634366989136}]
# [{'label': 'neutral', 'score': 0.7359733581542969}]
# [{'label': 'neutral', 'score': 0.9118258357048035}]
# [{'label': 'neutral', 'score': 0.9295461177825928}]
# [{'label': 'joy', 'score': 0.8605941534042358}]
# [{'label': 'surprise', 'score': 0.582942008972168}]
# [{'label': 'neutral', 'score': 0.9508327841758728}]
# [{'label': 'joy', 'score': 0.5063840746879578}]
# [{'label': 'surprise', 'score': 0.38744568824768066}]
# [{'label': 'anger', 'score': 0.9697082042694092}]
# [{'label': 'anger', 'score': 0.9697082042694092}]
# [{'label': 'anger', 'score': 0.9854955673217773}]
# [{'label': 'anger', 'score': 0.6459111571311951}]
# [{'label': 'anger', 'score': 0.9845424890518188}]
# [{'label': 'anger', 'score': 0.5635091066360474}]
# [{'label': 'anger', 'score': 0.9701794385910034}]
# [{'label': 'anger', 'score': 0.9228280782699585}]
# [{'label': 'anger', 'score': 0.4385918080806732}]
# [{'label': 'neutral', 'score': 0.8987126350402832}]
# [{'label': 'anger', 'score': 0.9275473952293396}]
# [{'label': 'neutral', 'score': 0.8146465420722961}]
# [{'label': 'anger', 'score': 0.5212537050247192}]
# [{'label': 'surprise', 'score': 0.9647595882415771}]
# [{'label': 'surprise', 'score': 0.8100809454917908}]
# [{'label': 'surprise', 'score': 0.7320793867111206}]
# [{'label': 'neutral', 'score': 0.9531099796295166}]
# [{'label': 'neutral', 'score': 0.9865843653678894}]
# [{'label': 'neutral', 'score': 0.96848464012146}]
# [{'label': 'neutral', 'score': 0.96848464012146}]
# [{'label': 'neutral', 'score': 0.9516144394874573}]
# [{'label': 'joy', 'score': 0.5125042796134949}]
# [{'label': 'sadness', 'score': 0.2593817412853241}]
# [{'label': 'neutral', 'score': 0.9214864373207092}]
# [{'label': 'anger', 'score': 0.9457445740699768}]
# [{'label': 'joy', 'score': 0.38111019134521484}]
# [{'label': 'neutral', 'score': 0.6879949569702148}]
# [{'label': 'neutral', 'score': 0.7672130465507507}]
# [{'label': 'sadness', 'score': 0.6234177947044373}]
# [{'label': 'neutral', 'score': 0.48959076404571533}]
# [{'label': 'neutral', 'score': 0.937305748462677}]
# [{'label': 'neutral', 'score': 0.8960931897163391}]
# [{'label': 'neutral', 'score': 0.9763660430908203}]
# [{'label': 'neutral', 'score': 0.9602710604667664}]
# [{'label': 'anger', 'score': 0.9302948117256165}]
# [{'label': 'neutral', 'score': 0.9777335524559021}]
# [{'label': 'neutral', 'score': 0.6666422486305237}]
# [{'label': 'neutral', 'score': 0.9751380085945129}]
# [{'label': 'joy', 'score': 0.6181787848472595}]
# [{'label': 'neutral', 'score': 0.8713619112968445}]
# [{'label': 'joy', 'score': 0.6181787848472595}]
# [{'label': 'neutral', 'score': 0.8507629036903381}]
# [{'label': 'joy', 'score': 0.6181787848472595}]
# [{'label': 'neutral', 'score': 0.9677950143814087}]
# [{'label': 'surprise', 'score': 0.7291447520256042}]
# [{'label': 'neutral', 'score': 0.9686874747276306}]
# [{'label': 'neutral', 'score': 0.926914632320404}]
# [{'label': 'neutral', 'score': 0.6848310828208923}]
# [{'label': 'surprise', 'score': 0.7339468002319336}]
# [{'label': 'neutral', 'score': 0.6223426461219788}]
# [{'label': 'neutral', 'score': 0.7374813556671143}]
# [{'label': 'neutral', 'score': 0.9596070051193237}]
# [{'label': 'surprise', 'score': 0.4953162670135498}]
# [{'label': 'neutral', 'score': 0.966312050819397}]
# [{'label': 'joy', 'score': 0.9060871005058289}]
# [{'label': 'surprise', 'score': 0.9552461504936218}]
# [{'label': 'neutral', 'score': 0.6745189428329468}]
# [{'label': 'anger', 'score': 0.960593581199646}]
# [{'label': 'anger', 'score': 0.9401788115501404}]
# [{'label': 'neutral', 'score': 0.5180572867393494}]
# [{'label': 'surprise', 'score': 0.4161418676376343}]
# [{'label': 'neutral', 'score': 0.9623010158538818}]
# [{'label': 'neutral', 'score': 0.8236691951751709}]
# [{'label': 'neutral', 'score': 0.8811383247375488}]
# [{'label': 'neutral', 'score': 0.9516144394874573}]
# [{'label': 'neutral', 'score': 0.9516144394874573}]
# [{'label': 'joy', 'score': 0.8229410648345947}]
# [{'label': 'neutral', 'score': 0.3937476575374603}]
# [{'label': 'surprise', 'score': 0.36557185649871826}]
# [{'label': 'joy', 'score': 0.8817238807678223}]
# [{'label': 'neutral', 'score': 0.9060381054878235}]
# [{'label': 'neutral', 'score': 0.8988493084907532}]
# [{'label': 'surprise', 'score': 0.9173307418823242}]
# [{'label': 'anger', 'score': 0.6964606046676636}]
# [{'label': 'sadness', 'score': 0.608670175075531}]
# [{'label': 'sadness', 'score': 0.3316810727119446}]
# [{'label': 'anger', 'score': 0.7318613529205322}]
# [{'label': 'anger', 'score': 0.8479222059249878}]
# [{'label': 'sadness', 'score': 0.2956174910068512}]
# [{'label': 'anger', 'score': 0.6632993221282959}]
# [{'label': 'neutral', 'score': 0.5672057867050171}]
# [{'label': 'neutral', 'score': 0.8278815746307373}]
# [{'label': 'anger', 'score': 0.4201819896697998}]
# [{'label': 'neutral', 'score': 0.7408322095870972}]
# [{'label': 'neutral', 'score': 0.6321008801460266}]
# [{'label': 'neutral', 'score': 0.5288593769073486}]
# [{'label': 'joy', 'score': 0.852645754814148}]
# [{'label': 'neutral', 'score': 0.7433767318725586}]
# [{'label': 'neutral', 'score': 0.9237173795700073}]
# [{'label': 'joy', 'score': 0.9003193974494934}]
# [{'label': 'joy', 'score': 0.6589232087135315}]
# [{'label': 'surprise', 'score': 0.44786569476127625}]
# [{'label': 'neutral', 'score': 0.8072095513343811}]
# [{'label': 'neutral', 'score': 0.8716312646865845}]
# [{'label': 'neutral', 'score': 0.465176522731781}]
# [{'label': 'anger', 'score': 0.8574733734130859}]
# [{'label': 'neutral', 'score': 0.7738799452781677}]
# [{'label': 'anger', 'score': 0.6365345120429993}]
# [{'label': 'neutral', 'score': 0.608117401599884}]
# [{'label': 'neutral', 'score': 0.9306375980377197}]
# [{'label': 'surprise', 'score': 0.46550053358078003}]
# [{'label': 'anger', 'score': 0.8041507005691528}]
# [{'label': 'anger', 'score': 0.7852705121040344}]
# [{'label': 'sadness', 'score': 0.6341285109519958}]
# [{'label': 'anger', 'score': 0.870941162109375}]
# [{'label': 'neutral', 'score': 0.9337747097015381}]
# [{'label': 'neutral', 'score': 0.9527337551116943}]
# [{'label': 'neutral', 'score': 0.9071717262268066}]
# [{'label': 'neutral', 'score': 0.851832926273346}]
# [{'label': 'joy', 'score': 0.7608250379562378}]
# [{'label': 'disgust', 'score': 0.8963794112205505}]
# [{'label': 'joy', 'score': 0.5566161274909973}]
# [{'label': 'surprise', 'score': 0.9578930735588074}]
# [{'label': 'neutral', 'score': 0.9199391007423401}]
# [{'label': 'neutral', 'score': 0.49309593439102173}]
# [{'label': 'joy', 'score': 0.9677022099494934}]
# [{'label': 'surprise', 'score': 0.8501530289649963}]
# [{'label': 'sadness', 'score': 0.7652798891067505}]
# [{'label': 'anger', 'score': 0.4042564332485199}]
# [{'label': 'neutral', 'score': 0.8890960812568665}]
# [{'label': 'neutral', 'score': 0.37385690212249756}]
# [{'label': 'anger', 'score': 0.408706396818161}]
# [{'label': 'neutral', 'score': 0.9818263053894043}]
# [{'label': 'neutral', 'score': 0.8641448020935059}]
# [{'label': 'neutral', 'score': 0.8644778728485107}]
# [{'label': 'neutral', 'score': 0.65059494972229}]
# [{'label': 'neutral', 'score': 0.6979096531867981}]
# [{'label': 'joy', 'score': 0.7883148193359375}]
# [{'label': 'neutral', 'score': 0.9686233997344971}]
# [{'label': 'neutral', 'score': 0.6061944365501404}]
# [{'label': 'neutral', 'score': 0.9331544637680054}]
# [{'label': 'joy', 'score': 0.8004570603370667}]
# [{'label': 'neutral', 'score': 0.8241698741912842}]
# [{'label': 'fear', 'score': 0.31308650970458984}]
# [{'label': 'neutral', 'score': 0.5735068321228027}]
# [{'label': 'sadness', 'score': 0.7747482061386108}]
# [{'label': 'sadness', 'score': 0.8806970119476318}]
# [{'label': 'sadness', 'score': 0.8507338166236877}]
# [{'label': 'neutral', 'score': 0.9888926148414612}]
# [{'label': 'joy', 'score': 0.9805166125297546}]
# [{'label': 'neutral', 'score': 0.9399178624153137}]
# [{'label': 'neutral', 'score': 0.9867970943450928}]
# [{'label': 'joy', 'score': 0.8895213603973389}]
# [{'label': 'joy', 'score': 0.6798674464225769}]
# [{'label': 'disgust', 'score': 0.5688461661338806}]
# [{'label': 'sadness', 'score': 0.6368442177772522}]
# [{'label': 'sadness', 'score': 0.920784592628479}]
# [{'label': 'neutral', 'score': 0.7957270741462708}]
# [{'label': 'neutral', 'score': 0.9694207310676575}]
# [{'label': 'neutral', 'score': 0.6399454474449158}]
# [{'label': 'neutral', 'score': 0.9754858016967773}]
# [{'label': 'neutral', 'score': 0.9487285017967224}]
# [{'label': 'neutral', 'score': 0.9381720423698425}]
# [{'label': 'neutral', 'score': 0.8482182025909424}]
# [{'label': 'anger', 'score': 0.9529559016227722}]
# [{'label': 'neutral', 'score': 0.9212168455123901}]
# [{'label': 'neutral', 'score': 0.983271062374115}]
# [{'label': 'neutral', 'score': 0.9126163721084595}]
# [{'label': 'neutral', 'score': 0.8259939551353455}]
# [{'label': 'neutral', 'score': 0.6756591796875}]
# [{'label': 'neutral', 'score': 0.9925212264060974}]
# [{'label': 'joy', 'score': 0.9311432242393494}]
# [{'label': 'joy', 'score': 0.8766478300094604}]
# [{'label': 'surprise', 'score': 0.9024314284324646}]
# [{'label': 'neutral', 'score': 0.958301842212677}]
# [{'label': 'surprise', 'score': 0.512815535068512}]
# [{'label': 'anger', 'score': 0.7869201898574829}]
# [{'label': 'neutral', 'score': 0.7751874327659607}]
# [{'label': 'joy', 'score': 0.8592697381973267}]
# [{'label': 'joy', 'score': 0.722155749797821}]
# [{'label': 'anger', 'score': 0.8516177535057068}]
# [{'label': 'anger', 'score': 0.9124699234962463}]
# [{'label': 'anger', 'score': 0.3600092828273773}]
# [{'label': 'joy', 'score': 0.8901680111885071}]
# [{'label': 'joy', 'score': 0.954658031463623}]
# [{'label': 'surprise', 'score': 0.6890066862106323}]
# [{'label': 'joy', 'score': 0.6024432182312012}]
# [{'label': 'neutral', 'score': 0.9245513677597046}]
# [{'label': 'neutral', 'score': 0.9434394836425781}]
# [{'label': 'neutral', 'score': 0.9310627579689026}]
# [{'label': 'sadness', 'score': 0.5730696320533752}]
# [{'label': 'neutral', 'score': 0.9896709322929382}]
# [{'label': 'surprise', 'score': 0.4161418676376343}]
# [{'label': 'joy', 'score': 0.8702976107597351}]
# [{'label': 'disgust', 'score': 0.44295579195022583}]
# [{'label': 'joy', 'score': 0.956364631652832}]
# [{'label': 'neutral', 'score': 0.8583974242210388}]
# [{'label': 'fear', 'score': 0.500992476940155}]
# [{'label': 'anger', 'score': 0.32148849964141846}]
# [{'label': 'neutral', 'score': 0.5452988743782043}]
# [{'label': 'neutral', 'score': 0.9084724187850952}]
# [{'label': 'neutral', 'score': 0.9770061373710632}]
# [{'label': 'neutral', 'score': 0.9267146587371826}]
# [{'label': 'surprise', 'score': 0.6836013197898865}]
# [{'label': 'neutral', 'score': 0.9562941789627075}]
# [{'label': 'surprise', 'score': 0.4854251742362976}]
# [{'label': 'neutral', 'score': 0.9603749513626099}]
# [{'label': 'neutral', 'score': 0.9657634496688843}]
# [{'label': 'neutral', 'score': 0.6295047402381897}]
# [{'label': 'neutral', 'score': 0.9258434176445007}]
# [{'label': 'neutral', 'score': 0.671861469745636}]
# [{'label': 'neutral', 'score': 0.8818155527114868}]
# [{'label': 'joy', 'score': 0.7232345938682556}]
# [{'label': 'joy', 'score': 0.8801788687705994}]
# [{'label': 'joy', 'score': 0.3727836012840271}]
# [{'label': 'neutral', 'score': 0.6916584968566895}]
# [{'label': 'neutral', 'score': 0.9840440154075623}]
# [{'label': 'neutral', 'score': 0.9751266837120056}]
# [{'label': 'neutral', 'score': 0.9334973692893982}]
# [{'label': 'fear', 'score': 0.7191858291625977}]
# [{'label': 'fear', 'score': 0.4282183051109314}]
# [{'label': 'neutral', 'score': 0.5576426982879639}]
# [{'label': 'neutral', 'score': 0.9224789142608643}]
# [{'label': 'joy', 'score': 0.9533649682998657}]
# [{'label': 'joy', 'score': 0.7783649563789368}]
# [{'label': 'anger', 'score': 0.42958322167396545}]
# [{'label': 'surprise', 'score': 0.9269900321960449}]
# [{'label': 'neutral', 'score': 0.5676133036613464}]
# [{'label': 'surprise', 'score': 0.6025260090827942}]
# [{'label': 'fear', 'score': 0.49729830026626587}]
# [{'label': 'neutral', 'score': 0.841468095779419}]
# [{'label': 'anger', 'score': 0.5626825094223022}]
# [{'label': 'neutral', 'score': 0.9007654786109924}]
# [{'label': 'neutral', 'score': 0.6175576448440552}]
# [{'label': 'neutral', 'score': 0.9467447400093079}]
# [{'label': 'neutral', 'score': 0.9490622282028198}]
# [{'label': 'neutral', 'score': 0.9718948602676392}]
# [{'label': 'neutral', 'score': 0.9653816819190979}]
# [{'label': 'neutral', 'score': 0.9734819531440735}]
# [{'label': 'neutral', 'score': 0.8739120364189148}]
# [{'label': 'neutral', 'score': 0.4228133261203766}]
# [{'label': 'neutral', 'score': 0.6129253506660461}]
# [{'label': 'neutral', 'score': 0.9296137690544128}]
# [{'label': 'neutral', 'score': 0.9442710280418396}]
# [{'label': 'neutral', 'score': 0.9808570146560669}]
# [{'label': 'fear', 'score': 0.6353297233581543}]
# [{'label': 'neutral', 'score': 0.8875448703765869}]
# [{'label': 'neutral', 'score': 0.9613132476806641}]
# [{'label': 'neutral', 'score': 0.87305748462677}]
# [{'label': 'joy', 'score': 0.963929295539856}]
# [{'label': 'neutral', 'score': 0.7371616959571838}]
# [{'label': 'sadness', 'score': 0.9289776682853699}]
# [{'label': 'sadness', 'score': 0.4489907920360565}]
# [{'label': 'neutral', 'score': 0.9759509563446045}]
# [{'label': 'neutral', 'score': 0.9705536961555481}]
# [{'label': 'neutral', 'score': 0.9640275239944458}]
# [{'label': 'sadness', 'score': 0.9408004879951477}]
# [{'label': 'neutral', 'score': 0.96848464012146}]
# [{'label': 'neutral', 'score': 0.7593904137611389}]
# [{'label': 'neutral', 'score': 0.9526783227920532}]
# [{'label': 'surprise', 'score': 0.6521922945976257}]
# [{'label': 'neutral', 'score': 0.8318144083023071}]
# [{'label': 'neutral', 'score': 0.937231719493866}]
# [{'label': 'neutral', 'score': 0.7392463088035583}]
# [{'label': 'neutral', 'score': 0.6227115988731384}]
# [{'label': 'sadness', 'score': 0.4291994571685791}]
# [{'label': 'joy', 'score': 0.6024432182312012}]
# [{'label': 'neutral', 'score': 0.9564454555511475}]
# [{'label': 'neutral', 'score': 0.5158231854438782}]
# [{'label': 'neutral', 'score': 0.7814595699310303}]
# [{'label': 'neutral', 'score': 0.9214951395988464}]
# [{'label': 'neutral', 'score': 0.9427013397216797}]
# [{'label': 'surprise', 'score': 0.9375922679901123}]
# [{'label': 'neutral', 'score': 0.8473618626594543}]
# [{'label': 'joy', 'score': 0.9781700372695923}]
# [{'label': 'sadness', 'score': 0.5782175064086914}]
# [{'label': 'anger', 'score': 0.5623340606689453}]
# [{'label': 'sadness', 'score': 0.8005013465881348}]
# [{'label': 'anger', 'score': 0.31254541873931885}]
# [{'label': 'joy', 'score': 0.9648124575614929}]
# [{'label': 'joy', 'score': 0.6024432182312012}]
# [{'label': 'neutral', 'score': 0.9564454555511475}]
# [{'label': 'neutral', 'score': 0.4943833649158478}]
# [{'label': 'neutral', 'score': 0.9559093117713928}]
# [{'label': 'joy', 'score': 0.8700224161148071}]
# [{'label': 'surprise', 'score': 0.9489997029304504}]
# [{'label': 'joy', 'score': 0.9023464918136597}]
# [{'label': 'anger', 'score': 0.3600092828273773}]
# [{'label': 'sadness', 'score': 0.34158405661582947}]
# [{'label': 'anger', 'score': 0.505117654800415}]
# [{'label': 'fear', 'score': 0.38256388902664185}]
# [{'label': 'anger', 'score': 0.7241866588592529}]
# [{'label': 'neutral', 'score': 0.8047832250595093}]
# [{'label': 'neutral', 'score': 0.6105132699012756}]
# [{'label': 'neutral', 'score': 0.9017969369888306}]
# [{'label': 'disgust', 'score': 0.5271211862564087}]
# [{'label': 'neutral', 'score': 0.824244499206543}]
# [{'label': 'neutral', 'score': 0.804405152797699}]
# [{'label': 'neutral', 'score': 0.8831390142440796}]
# [{'label': 'neutral', 'score': 0.7236864566802979}]
# [{'label': 'neutral', 'score': 0.9229410290718079}]
# [{'label': 'neutral', 'score': 0.7579757571220398}]
# ...
# [{'label': 'neutral', 'score': 0.7987244725227356}]
# [{'label': 'sadness', 'score': 0.6853114366531372}]
# [{'label': 'joy', 'score': 0.8891449570655823}]
# [{'label': 'neutral', 'score': 0.6068111062049866}]
# [{'label': 'sadness', 'score': 0.3986590802669525}]
# [{'label': 'joy', 'score': 0.7940474152565002}]
# [{'label': 'joy', 'score': 0.8641494512557983}]
# [{'label': 'neutral', 'score': 0.4243890345096588}]
# [{'label': 'sadness', 'score': 0.5271122455596924}]
# [{'label': 'neutral', 'score': 0.9788272380828857}]
# [{'label': 'neutral', 'score': 0.5679739713668823}]
# [{'label': 'neutral', 'score': 0.9098243713378906}]
# [{'label': 'neutral', 'score': 0.9762766361236572}]
# [{'label': 'neutral', 'score': 0.8383074998855591}]
# [{'label': 'neutral', 'score': 0.8375734686851501}]
# [{'label': 'neutral', 'score': 0.8795508742332458}]
# [{'label': 'neutral', 'score': 0.32513004541397095}]
# [{'label': 'joy', 'score': 0.6117776036262512}]
# [{'label': 'anger', 'score': 0.754687488079071}]
# [{'label': 'neutral', 'score': 0.9343127012252808}]
# [{'label': 'neutral', 'score': 0.8728057742118835}]
# [{'label': 'neutral', 'score': 0.8939467668533325}]
# [{'label': 'neutral', 'score': 0.8016815185546875}]
# [{'label': 'neutral', 'score': 0.8704906702041626}]
# [{'label': 'neutral', 'score': 0.9567864537239075}]
# [{'label': 'neutral', 'score': 0.9557276368141174}]
# [{'label': 'neutral', 'score': 0.8218436241149902}]
# [{'label': 'joy', 'score': 0.6787908673286438}]
# [{'label': 'sadness', 'score': 0.7272217273712158}]
# [{'label': 'neutral', 'score': 0.9091952443122864}]
# [{'label': 'neutral', 'score': 0.45837467908859253}]
# [{'label': 'neutral', 'score': 0.8645164370536804}]
# [{'label': 'neutral', 'score': 0.9313130974769592}]
# [{'label': 'sadness', 'score': 0.4055045545101166}]
# [{'label': 'anger', 'score': 0.9699882864952087}]
# [{'label': 'anger', 'score': 0.818219006061554}]
# [{'label': 'anger', 'score': 0.7529613971710205}]
# [{'label': 'surprise', 'score': 0.8728556632995605}]
# [{'label': 'sadness', 'score': 0.9317485690116882}]
# [{'label': 'neutral', 'score': 0.7848876118659973}]
# [{'label': 'surprise', 'score': 0.5446189641952515}]
# [{'label': 'neutral', 'score': 0.7302899360656738}]
# [{'label': 'surprise', 'score': 0.8836777806282043}]
# [{'label': 'joy', 'score': 0.7928913235664368}]
# [{'label': 'joy', 'score': 0.7928913235664368}]
# [{'label': 'anger', 'score': 0.9832907915115356}]
# [{'label': 'sadness', 'score': 0.40340250730514526}]
# [{'label': 'neutral', 'score': 0.8172626495361328}]
# [{'label': 'surprise', 'score': 0.567410945892334}]
# [{'label': 'surprise', 'score': 0.38690242171287537}]
# [{'label': 'neutral', 'score': 0.7368210554122925}]
# [{'label': 'sadness', 'score': 0.39021065831184387}]
# [{'label': 'sadness', 'score': 0.681077241897583}]
# [{'label': 'neutral', 'score': 0.8694148063659668}]
# [{'label': 'neutral', 'score': 0.6981351971626282}]
# [{'label': 'sadness', 'score': 0.6766442060470581}]
# [{'label': 'joy', 'score': 0.67348712682724}]
# [{'label': 'neutral', 'score': 0.8531674146652222}]
# [{'label': 'sadness', 'score': 0.586139976978302}]
# [{'label': 'surprise', 'score': 0.9595330953598022}]
# [{'label': 'anger', 'score': 0.9070016741752625}]
# [{'label': 'joy', 'score': 0.37027662992477417}]
# [{'label': 'neutral', 'score': 0.7252543568611145}]
# [{'label': 'sadness', 'score': 0.6516267657279968}]
# [{'label': 'neutral', 'score': 0.8150097727775574}]
# [{'label': 'surprise', 'score': 0.9446930885314941}]
# [{'label': 'neutral', 'score': 0.9240890741348267}]
# [{'label': 'joy', 'score': 0.7826824188232422}]
# [{'label': 'surprise', 'score': 0.562400221824646}]
# [{'label': 'neutral', 'score': 0.9861168265342712}]
# [{'label': 'neutral', 'score': 0.7423686981201172}]
# [{'label': 'joy', 'score': 0.9630156755447388}]
# [{'label': 'neutral', 'score': 0.9702578783035278}]
# [{'label': 'neutral', 'score': 0.6254243850708008}]
# [{'label': 'neutral', 'score': 0.4030391275882721}]
# [{'label': 'neutral', 'score': 0.7516544461250305}]
# [{'label': 'neutral', 'score': 0.8887432813644409}]
# [{'label': 'surprise', 'score': 0.34147924184799194}]
# [{'label': 'fear', 'score': 0.5285210013389587}]
# [{'label': 'anger', 'score': 0.9159302711486816}]
# [{'label': 'neutral', 'score': 0.7800981402397156}]
# [{'label': 'surprise', 'score': 0.5867405533790588}]
# [{'label': 'neutral', 'score': 0.717939019203186}]
# [{'label': 'neutral', 'score': 0.9760837554931641}]
# [{'label': 'neutral', 'score': 0.9393193125724792}]
# [{'label': 'disgust', 'score': 0.43293046951293945}]
# [{'label': 'neutral', 'score': 0.4696520268917084}]
# [{'label': 'joy', 'score': 0.955454409122467}]
# [{'label': 'neutral', 'score': 0.809429407119751}]
# [{'label': 'neutral', 'score': 0.46142470836639404}]
# [{'label': 'anger', 'score': 0.8813901543617249}]
# [{'label': 'neutral', 'score': 0.8656879663467407}]
# [{'label': 'surprise', 'score': 0.8926460146903992}]
# [{'label': 'neutral', 'score': 0.6046486496925354}]
# [{'label': 'neutral', 'score': 0.5296796560287476}]
# [{'label': 'joy', 'score': 0.6139903664588928}]
# [{'label': 'joy', 'score': 0.609698474407196}]
# [{'label': 'surprise', 'score': 0.8623173236846924}]
# [{'label': 'neutral', 'score': 0.8987298011779785}]
# [{'label': 'sadness', 'score': 0.4475533068180084}]
# [{'label': 'surprise', 'score': 0.8800926208496094}]
# [{'label': 'joy', 'score': 0.5200983881950378}]
# [{'label': 'sadness', 'score': 0.4692804217338562}]
# [{'label': 'neutral', 'score': 0.8296544551849365}]
# [{'label': 'neutral', 'score': 0.7751874327659607}]
# [{'label': 'neutral', 'score': 0.9733731746673584}]
# [{'label': 'joy', 'score': 0.9842908382415771}]
# [{'label': 'joy', 'score': 0.6999345421791077}]
# [{'label': 'neutral', 'score': 0.4892199635505676}]
# [{'label': 'neutral', 'score': 0.8316066861152649}]
# [{'label': 'neutral', 'score': 0.914735734462738}]
# [{'label': 'neutral', 'score': 0.9522171020507812}]
# [{'label': 'neutral', 'score': 0.5137612223625183}]
# [{'label': 'neutral', 'score': 0.5994412899017334}]
# [{'label': 'neutral', 'score': 0.5801898241043091}]
# [{'label': 'neutral', 'score': 0.7716754078865051}]
# [{'label': 'anger', 'score': 0.7296039462089539}]
# [{'label': 'joy', 'score': 0.8644447326660156}]
# [{'label': 'neutral', 'score': 0.9793827533721924}]
# [{'label': 'joy', 'score': 0.7583536505699158}]
# [{'label': 'joy', 'score': 0.8985335826873779}]
# [{'label': 'surprise', 'score': 0.9578930735588074}]
# [{'label': 'neutral', 'score': 0.95113205909729}]
# [{'label': 'neutral', 'score': 0.6056838035583496}]
# [{'label': 'neutral', 'score': 0.8223637938499451}]
# [{'label': 'neutral', 'score': 0.8143280148506165}]
# [{'label': 'neutral', 'score': 0.9682860970497131}]
# [{'label': 'joy', 'score': 0.7060725092887878}]
# [{'label': 'anger', 'score': 0.5529242157936096}]
# [{'label': 'neutral', 'score': 0.6791320443153381}]
# [{'label': 'anger', 'score': 0.591084361076355}]
# [{'label': 'disgust', 'score': 0.772355854511261}]
# [{'label': 'anger', 'score': 0.7684786319732666}]
# [{'label': 'anger', 'score': 0.9866841435432434}]
# [{'label': 'anger', 'score': 0.8570923805236816}]
# [{'label': 'neutral', 'score': 0.6645773649215698}]
# [{'label': 'anger', 'score': 0.7773571014404297}]
# [{'label': 'joy', 'score': 0.9553300738334656}]
# [{'label': 'fear', 'score': 0.25129130482673645}]
# [{'label': 'neutral', 'score': 0.6533017158508301}]
# [{'label': 'joy', 'score': 0.6283146142959595}]
# [{'label': 'surprise', 'score': 0.9034126996994019}]
# [{'label': 'neutral', 'score': 0.9598703980445862}]
# [{'label': 'neutral', 'score': 0.9651614427566528}]
# [{'label': 'neutral', 'score': 0.8165513277053833}]
# [{'label': 'joy', 'score': 0.9846165180206299}]
# [{'label': 'joy', 'score': 0.5574588775634766}]
# [{'label': 'fear', 'score': 0.3406777083873749}]
# [{'label': 'anger', 'score': 0.43829771876335144}]
# [{'label': 'joy', 'score': 0.8852024078369141}]
# [{'label': 'joy', 'score': 0.956364631652832}]
# [{'label': 'neutral', 'score': 0.974478006362915}]
# [{'label': 'anger', 'score': 0.4612782597541809}]
# [{'label': 'neutral', 'score': 0.6743151545524597}]
# [{'label': 'neutral', 'score': 0.48025354743003845}]
# [{'label': 'neutral', 'score': 0.9522747993469238}]
# [{'label': 'neutral', 'score': 0.8988493084907532}]
# [{'label': 'joy', 'score': 0.6181787848472595}]
# [{'label': 'joy', 'score': 0.7929428219795227}]
# [{'label': 'surprise', 'score': 0.9251897931098938}]
# [{'label': 'surprise', 'score': 0.9038238525390625}]
# [{'label': 'neutral', 'score': 0.8663060665130615}]
# [{'label': 'surprise', 'score': 0.5852063894271851}]
# [{'label': 'disgust', 'score': 0.7758209705352783}]
# [{'label': 'joy', 'score': 0.9316896796226501}]
# [{'label': 'neutral', 'score': 0.9868190288543701}]
# [{'label': 'joy', 'score': 0.8377354741096497}]
# [{'label': 'neutral', 'score': 0.962877631187439}]
# [{'label': 'joy', 'score': 0.6186771988868713}]
# [{'label': 'neutral', 'score': 0.96848464012146}]
# [{'label': 'neutral', 'score': 0.975140392780304}]
# [{'label': 'neutral', 'score': 0.9801597595214844}]
# [{'label': 'joy', 'score': 0.5490357279777527}]
# [{'label': 'surprise', 'score': 0.8610079288482666}]
# [{'label': 'neutral', 'score': 0.9516144394874573}]
# [{'label': 'neutral', 'score': 0.9564454555511475}]
# [{'label': 'neutral', 'score': 0.9775394201278687}]
# [{'label': 'neutral', 'score': 0.9554504156112671}]
# [{'label': 'neutral', 'score': 0.949536144733429}]
# [{'label': 'neutral', 'score': 0.74818354845047}]
# [{'label': 'surprise', 'score': 0.5776274800300598}]
# [{'label': 'sadness', 'score': 0.45014747977256775}]
# [{'label': 'neutral', 'score': 0.8219422101974487}]
# [{'label': 'sadness', 'score': 0.9025418162345886}]
# [{'label': 'surprise', 'score': 0.6063690781593323}]
# [{'label': 'anger', 'score': 0.3326025605201721}]
# [{'label': 'surprise', 'score': 0.9766454696655273}]
# [{'label': 'joy', 'score': 0.9261351227760315}]
# [{'label': 'neutral', 'score': 0.7938967347145081}]
# [{'label': 'joy', 'score': 0.9138376116752625}]
# [{'label': 'neutral', 'score': 0.9571799039840698}]
# [{'label': 'neutral', 'score': 0.9613019227981567}]
# [{'label': 'neutral', 'score': 0.9580905437469482}]
# [{'label': 'joy', 'score': 0.4126499891281128}]
# [{'label': 'neutral', 'score': 0.8062901496887207}]
# [{'label': 'neutral', 'score': 0.982346773147583}]
# [{'label': 'neutral', 'score': 0.9428836107254028}]
# [{'label': 'anger', 'score': 0.6428049802780151}]
# [{'label': 'anger', 'score': 0.5006417036056519}]
# [{'label': 'neutral', 'score': 0.9472883939743042}]
# [{'label': 'joy', 'score': 0.7722097039222717}]
# [{'label': 'surprise', 'score': 0.948646068572998}]
# [{'label': 'surprise', 'score': 0.5209370851516724}]
# [{'label': 'surprise', 'score': 0.91875159740448}]
# [{'label': 'neutral', 'score': 0.6327448487281799}]
# [{'label': 'anger', 'score': 0.4983561635017395}]
# [{'label': 'fear', 'score': 0.367971807718277}]
# [{'label': 'neutral', 'score': 0.9557563066482544}]
# [{'label': 'neutral', 'score': 0.9699049592018127}]
# [{'label': 'neutral', 'score': 0.4403395354747772}]
# [{'label': 'neutral', 'score': 0.9049782156944275}]
# [{'label': 'neutral', 'score': 0.9729992747306824}]
# [{'label': 'neutral', 'score': 0.5439165830612183}]
# [{'label': 'neutral', 'score': 0.968447744846344}]
# [{'label': 'joy', 'score': 0.8871477246284485}]
# [{'label': 'neutral', 'score': 0.9495285153388977}]
# [{'label': 'neutral', 'score': 0.6324641108512878}]
# [{'label': 'neutral', 'score': 0.827123761177063}]
# [{'label': 'surprise', 'score': 0.7985033988952637}]
# [{'label': 'surprise', 'score': 0.5859228372573853}]
# [{'label': 'surprise', 'score': 0.73347407579422}]
# [{'label': 'neutral', 'score': 0.9779244065284729}]
# [{'label': 'neutral', 'score': 0.9516144394874573}]
# [{'label': 'neutral', 'score': 0.9516144394874573}]
# [{'label': 'neutral', 'score': 0.9360380172729492}]
# [{'label': 'neutral', 'score': 0.96848464012146}]
# [{'label': 'neutral', 'score': 0.47241467237472534}]
# [{'label': 'neutral', 'score': 0.9605758190155029}]
# [{'label': 'anger', 'score': 0.3897399306297302}]
# [{'label': 'neutral', 'score': 0.9516944289207458}]
# [{'label': 'neutral', 'score': 0.9843655824661255}]
# [{'label': 'neutral', 'score': 0.96848464012146}]
# [{'label': 'neutral', 'score': 0.9781836867332458}]
# [{'label': 'sadness', 'score': 0.6457880735397339}]
# [{'label': 'joy', 'score': 0.947786271572113}]
# [{'label': 'joy', 'score': 0.6172506213188171}]
# [{'label': 'neutral', 'score': 0.9487718343734741}]
# [{'label': 'neutral', 'score': 0.9669742584228516}]
# [{'label': 'neutral', 'score': 0.9844301342964172}]
# [{'label': 'joy', 'score': 0.7589672207832336}]
# [{'label': 'neutral', 'score': 0.9789795875549316}]
# [{'label': 'neutral', 'score': 0.9366363883018494}]
# [{'label': 'neutral', 'score': 0.9484184980392456}]
# [{'label': 'neutral', 'score': 0.8783210515975952}]
# [{'label': 'neutral', 'score': 0.9427258968353271}]
# [{'label': 'surprise', 'score': 0.39049407839775085}]
# [{'label': 'neutral', 'score': 0.8669686913490295}]
# [{'label': 'joy', 'score': 0.8279241919517517}]
# [{'label': 'neutral', 'score': 0.9113237857818604}]
# [{'label': 'surprise', 'score': 0.9546017646789551}]
# [{'label': 'surprise', 'score': 0.45259761810302734}]
# [{'label': 'surprise', 'score': 0.39705929160118103}]
# [{'label': 'neutral', 'score': 0.8379231095314026}]
# [{'label': 'neutral', 'score': 0.9847577810287476}]
# [{'label': 'neutral', 'score': 0.9795280694961548}]
# [{'label': 'neutral', 'score': 0.8603439331054688}]
# [{'label': 'surprise', 'score': 0.8803061246871948}]
# [{'label': 'neutral', 'score': 0.6028488278388977}]
# [{'label': 'neutral', 'score': 0.797027051448822}]
# [{'label': 'neutral', 'score': 0.7806025743484497}]
# [{'label': 'neutral', 'score': 0.8209213614463806}]
# [{'label': 'neutral', 'score': 0.7894061803817749}]
# [{'label': 'surprise', 'score': 0.8625423312187195}]
# [{'label': 'anger', 'score': 0.5519525408744812}]
# [{'label': 'neutral', 'score': 0.907207727432251}]
# [{'label': 'surprise', 'score': 0.7251261472702026}]
# [{'label': 'neutral', 'score': 0.8545944690704346}]
# [{'label': 'neutral', 'score': 0.9639310240745544}]
# [{'label': 'anger', 'score': 0.7756173610687256}]
# [{'label': 'neutral', 'score': 0.67896568775177}]
# [{'label': 'neutral', 'score': 0.6927881240844727}]
# [{'label': 'joy', 'score': 0.94087815284729}]
# [{'label': 'joy', 'score': 0.8852024078369141}]
# [{'label': 'neutral', 'score': 0.966608464717865}]
# [{'label': 'neutral', 'score': 0.966608464717865}]
# [{'label': 'neutral', 'score': 0.966608464717865}]
# [{'label': 'neutral', 'score': 0.8920646905899048}]
# [{'label': 'neutral', 'score': 0.9564454555511475}]
# [{'label': 'neutral', 'score': 0.8236421942710876}]
# [{'label': 'disgust', 'score': 0.8181073069572449}]
# [{'label': 'surprise', 'score': 0.7239630222320557}]
# [{'label': 'neutral', 'score': 0.9355712532997131}]
# [{'label': 'joy', 'score': 0.9182564616203308}]
# [{'label': 'neutral', 'score': 0.8013932704925537}]
# [{'label': 'surprise', 'score': 0.4656091034412384}]
# [{'label': 'neutral', 'score': 0.9698222875595093}]
# [{'label': 'surprise', 'score': 0.9555693864822388}]
# [{'label': 'sadness', 'score': 0.7961540818214417}]
# [{'label': 'joy', 'score': 0.8382340669631958}]
# [{'label': 'neutral', 'score': 0.7192696928977966}]
# [{'label': 'joy', 'score': 0.888277530670166}]
# [{'label': 'neutral', 'score': 0.885646402835846}]
# [{'label': 'joy', 'score': 0.9651906490325928}]
# [{'label': 'joy', 'score': 0.9644437432289124}]
# [{'label': 'neutral', 'score': 0.9240002036094666}]
# [{'label': 'neutral', 'score': 0.85682612657547}]
# [{'label': 'anger', 'score': 0.8092573285102844}]
# [{'label': 'anger', 'score': 0.8809598684310913}]
# [{'label': 'anger', 'score': 0.8734190464019775}]
# [{'label': 'anger', 'score': 0.5578402280807495}]
# [{'label': 'anger', 'score': 0.8092573285102844}]
# [{'label': 'neutral', 'score': 0.9775521755218506}]
# [{'label': 'neutral', 'score': 0.8605528473854065}]
# [{'label': 'anger', 'score': 0.26293545961380005}]
# [{'label': 'neutral', 'score': 0.9621578454971313}]
# [{'label': 'neutral', 'score': 0.5309793949127197}]
# [{'label': 'neutral', 'score': 0.5288728475570679}]
# [{'label': 'neutral', 'score': 0.8430692553520203}]
# [{'label': 'anger', 'score': 0.7179040908813477}]
# [{'label': 'joy', 'score': 0.49825313687324524}]
# [{'label': 'neutral', 'score': 0.770958662033081}]
# [{'label': 'neutral', 'score': 0.8389543294906616}]

# %%
final_concatenation = list()

for i in range(len(inference01)):
    if max(float(inference01[i][1]), float(inference02[i][1])) == float(inference01[i][1]):
        final_concatenation.append(inference01[i][0])
    elif max(float(inference01[i][1]), float(inference02[i][1])) == float(inference02[i][1]):
        final_concatenation.append(inference02[i][0])
    elif float(inference01[i][0]) == float(inference02[i][0]) :
        final_concatenation.append(inference01[i][0])

# %%
submit = pd.read_csv('./sample_submission.csv')
submit['Target'] = final_concatenation
submit.to_csv('./concatenation_submission.csv', index=False)
